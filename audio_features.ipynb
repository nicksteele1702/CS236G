# %%
import librosa
import Signal_Analysis.features.signal as sig
import numpy as np
import math
import os
import pickle
import re
import soundfile as sf
from googlesearch import search
import yfinance as yf
from dateutil import parser
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %%
def find_nth(haystack, needle, n):
    start = haystack.find(needle)
    while start >= 0 and n > 1:
        start = haystack.find(needle, start+len(needle))
        n -= 1
    return start

# %%
#compute dict of {date:[{company:{feature:value}}]}
data_master = {}
num_calls = 0
for root, dirs, files in os.walk("ReleasedDataset_mp3"):
    for directory in dirs:
        try:
            if (directory == 'Audio'):
                continue
            company_name = directory[:directory.index('_')]
            date = directory[directory.index('_')+1:]
            num_calls += 1
            print (num_calls)

            audio_list = []
            sr = 0
            #create feature map
            for root, dirs, files in os.walk("ReleasedDataset_mp3/"+directory+'/Audio'):
                

                files_sorted = {}
                for file in files:
                    first_val = file[file.index('_')+1:find_nth(file, '_', 2)]
                    second_val = file[find_nth(file, '_', 2)+1: find_nth(file, '.', 2)]
                    first_val = int(re.sub("[^0-9]", "", first_val))
                    second_val = int(re.sub("[^0-9]", "", second_val))
                    file_index = (first_val, second_val)
                    files_sorted[file_index] = file

                for file_key in sorted(files_sorted.keys()):
                    file = files_sorted[file_key]
                    audio_path = "ReleasedDataset_mp3/"+directory+'/Audio/' + file
                    signal, sr = librosa.load(audio_path)
                    audio_list.append(signal)
            audio_list = np.concatenate(audio_list)
            sf.write('audio_list.wav', audio_list, sr)
            data, sr = sf.read('audio_list.wav')

            audio_features = compute_audio_features(data, sr)
            company_dict = {company_name:audio_features}




            if (date not in data_master.keys()):
                data_master[date] = [company_dict]
            else:
                data_master[date].append(company_dict)
            with open('data_master.pickle', 'wb') as handle:
                pickle.dump(data_master, handle, protocol=pickle.HIGHEST_PROTOCOL)
        except:
            continue

# %%
data_master

# %%
import json
with open('master_features.txt', 'r') as file:
    data_master = json.load(file)

# %%
data_master
# Out:
# {'20170803': [{'Becton Dickinson': {'minimum_pitch': 216.75435,
#     'maximum_pitch': 3595.1587,
#     'median_f0': [[103.16901408450703]],
#     'number_of_pulses': 407,
#     'jitter_local': 0.050096107778580694,
#     'jitter_local_absolute': 0.00042484750853803553,
#     'jitter_rap': 0.026665996818046236,
#     'jitter_ppq5': 0.028850062408851376,
#     'jitter_ddp': 0.0799979904541387,
#     'max_db': 58.66719853886681,
#     'min_db': 20.09671816966296,
#     'mean_db': 35.013663136723174,
#     'HNR': 6.097161801484113,
#     'VADER_neg': 0.021,
#     'VADER_neu': 0.844,
#     'VADER_pos': 0.135,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 0.5864349007606506,
#     'finBERT_neg': -0.3480337858200073,
#     'finBERT_neu': -0.7337027192115784}},
#   {'Ball Corp': {'minimum_pitch': 154.0751,
#     'maximum_pitch': 3318.2476,
#     'median_f0': [[117.5133689839572]],
#     'number_of_pulses': 755,
#     'jitter_local': 0.05932506437639114,
#     'jitter_local_absolute': 0.0004182898411798934,
#     'jitter_rap': 0.03077454158827009,
#     'jitter_ppq5': 0.035649824533916546,
#     'jitter_ddp': 0.09232362476481028,
#     'max_db': 56.755577131997256,
#     'min_db': 18.313351769507833,
#     'mean_db': 31.049336492797053,
#     'HNR': 8.397460444755222,
#     'VADER_neg': 0.02,
#     'VADER_neu': 0.845,
#     'VADER_pos': 0.135,
#     'VADER_compound': 1.0,
#     'finBERT_pos': -0.772621214389801,
#     'finBERT_neg': -0.6029770374298096,
#     'finBERT_neu': 0.6605687141418457}},
#   {'FleetCor Technologies Inc': {'minimum_pitch': 149.79308,
#     'maximum_pitch': 1562.907,
#     'median_f0': [[112.69230769230768]],
#     'number_of_pulses': 617,
#     'jitter_local': 0.05709491883104115,
#     'jitter_local_absolute': 0.0004398012027221887,
#     'jitter_rap': 0.028022704256526882,
#     'jitter_ppq5': 0.029021736136206455,
#     'jitter_ddp': 0.08406811276958065,
#     'max_db': 47.6328435358277,
#     'min_db': 19.33774569705067,
#     'mean_db': 30.734205496643558,
#     'HNR': 7.118712735514113,
#     'VADER_neg': 0.043,
#     'VADER_neu': 0.815,
#     'VADER_pos': 0.141,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 2.112043857574463,
#     'finBERT_neg': -1.2189799547195435,
#     'finBERT_neu': -0.7600986361503601}},
#   {'Church & Dwight': {'minimum_pitch': 147.26869,
#     'maximum_pitch': 3652.5098,
#     'median_f0': [[122.08333333333333]],
#     'number_of_pulses': 710,
#     'jitter_local': 0.050699285661280485,
#     'jitter_local_absolute': 0.00033436823784624366,
#     'jitter_rap': 0.0255361688717331,
#     'jitter_ppq5': 0.02655955866134844,
#     'jitter_ddp': 0.0766085066151993,
#     'max_db': 60.739980959922555,
#     'min_db': 7.986817770912699,
#     'mean_db': 28.955442853966314,
#     'HNR': 7.907822249928895,
#     'VADER_neg': 0.051,
#     'VADER_neu': 0.84,
#     'VADER_pos': 0.11,
#     'VADER_compound': 0.9991,
#     'finBERT_pos': -0.2430131435394287,
#     'finBERT_neg': 1.5459827184677124,
#     'finBERT_neu': -2.2886738777160645}},
#   {'Yum! Brands Inc': {'minimum_pitch': 167.23164,
#     'maximum_pitch': 548.5099,
#     'median_f0': [[122.08333333333333]],
#     'number_of_pulses': 310,
#     'jitter_local': 0.09501021140365501,
#     'jitter_local_absolute': 0.00045705318053880305,
#     'jitter_rap': 0.05182929776231187,
#     'jitter_ppq5': 0.06589467661363052,
#     'jitter_ddp': 0.1554878932869356,
#     'max_db': 155.84800965798533,
#     'min_db': 16.562509649073288,
#     'mean_db': 35.748520364412315,
#     'HNR': 5.4173907615209025,
#     'VADER_neg': 0.008,
#     'VADER_neu': 0.781,
#     'VADER_pos': 0.211,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 2.394772529602051,
#     'finBERT_neg': -2.3094959259033203,
#     'finBERT_neu': 0.39837056398391724}},
#   {'Stericycle Inc': {'minimum_pitch': 0.0,
#     'maximum_pitch': 3600.7888,
#     'median_f0': [[131.58682634730536]],
#     'number_of_pulses': 1998,
#     'jitter_local': 0.07102844531266543,
#     'jitter_local_absolute': 0.0005125510582700241,
#     'jitter_rap': 0.03787420257605626,
#     'jitter_ppq5': 0.04351250376325785,
#     'jitter_ddp': 0.11362260772816879,
#     'max_db': 88.34004488254982,
#     'min_db': 13.95701403491622,
#     'mean_db': 29.970793139215886,
#     'HNR': 6.747848743106196,
#     'VADER_neg': 0.021,
#     'VADER_neu': 0.887,
#     'VADER_pos': 0.093,
#     'VADER_compound': 0.999,
#     'finBERT_pos': -1.324453353881836,
#     'finBERT_neg': 1.7231348752975464,
#     'finBERT_neu': -0.6910530924797058}},
#   {'AmerisourceBergen Corp': {'minimum_pitch': 220.6302,
#     'maximum_pitch': 2875.8982,
#     'median_f0': [[108.7871287128713]],
#     'number_of_pulses': 323,
#     'jitter_local': 0.078442928039704,
#     'jitter_local_absolute': 0.00047789844861421634,
#     'jitter_rap': 0.04022129943788806,
#     'jitter_ppq5': 0.046540942928040174,
#     'jitter_ddp': 0.12066389831366418,
#     'max_db': 93.36399478398279,
#     'min_db': 20.7949235471218,
#     'mean_db': 32.46191761517191,
#     'HNR': 5.598824195210686,
#     'VADER_neg': 0.027,
#     'VADER_neu': 0.821,
#     'VADER_pos': 0.151,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': -1.26002037525177,
#     'finBERT_neg': 2.4972753524780273,
#     'finBERT_neu': -1.7031363248825073}},
#   {'Cognizant Technology Solutions': {'minimum_pitch': 174.96558,
#     'maximum_pitch': 2462.417,
#     'median_f0': [[430.88235294117646]],
#     'number_of_pulses': 1013,
#     'jitter_local': 0.09678992219245301,
#     'jitter_local_absolute': 0.0002749591015069495,
#     'jitter_rap': 0.049330096337576096,
#     'jitter_ppq5': 0.05481062567723277,
#     'jitter_ddp': 0.1479902890127283,
#     'max_db': 68.23228232957229,
#     'min_db': 20.68488480287771,
#     'mean_db': 38.39782593349023,
#     'HNR': 5.374422539596009,
#     'VADER_neg': 0.014,
#     'VADER_neu': 0.84,
#     'VADER_pos': 0.146,
#     'VADER_compound': 0.9998,
#     'finBERT_pos': 1.6534197330474854,
#     'finBERT_neg': -2.655557870864868,
#     'finBERT_neu': 1.0744332075119019}},
#   {'Kellogg Co.': {'minimum_pitch': 185.57716,
#     'maximum_pitch': 3380.1272,
#     'median_f0': [[120.08196721311475]],
#     'number_of_pulses': 1589,
#     'jitter_local': 0.09227137353349275,
#     'jitter_local_absolute': 0.0005154567091713176,
#     'jitter_rap': 0.05110417398064208,
#     'jitter_ppq5': 0.06078716168632032,
#     'jitter_ddp': 0.15331252194192624,
#     'max_db': 61.05326971440353,
#     'min_db': 13.491009946762137,
#     'mean_db': 26.569461175038004,
#     'HNR': 4.850237166210615,
#     'VADER_neg': 0.013,
#     'VADER_neu': 0.813,
#     'VADER_pos': 0.174,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 1.658275842666626,
#     'finBERT_neg': -2.194359302520752,
#     'finBERT_neu': 0.44214367866516113}},
#   {'Regeneron': {'minimum_pitch': 148.04639,
#     'maximum_pitch': 2780.4502,
#     'median_f0': [[124.15254237288136]],
#     'number_of_pulses': 1244,
#     'jitter_local': 0.059856503412422345,
#     'jitter_local_absolute': 0.00034781919793478474,
#     'jitter_rap': 0.03059150853233028,
#     'jitter_ppq5': 0.03480077114373606,
#     'jitter_ddp': 0.09177452559699084,
#     'max_db': 69.72442241836265,
#     'min_db': 10.645363233483412,
#     'mean_db': 28.361859357312632,
#     'HNR': 9.662713699960575,
#     'VADER_neg': 0.033,
#     'VADER_neu': 0.894,
#     'VADER_pos': 0.073,
#     'VADER_compound': 0.9989,
#     'finBERT_pos': 1.5596487522125244,
#     'finBERT_neg': -2.7230381965637207,
#     'finBERT_neu': 1.1063182353973389}},
#   {'Allergan, Plc': {'minimum_pitch': 0.0,
#     'maximum_pitch': 3288.257,
#     'median_f0': [[98.10267857142856]],
#     'number_of_pulses': 1371,
#     'jitter_local': 0.07455424055280709,
#     'jitter_local_absolute': 0.0006814648456613661,
#     'jitter_rap': 0.04059640107911996,
#     'jitter_ppq5': 0.04412600272951799,
#     'jitter_ddp': 0.12178920323735987,
#     'max_db': 72.78496622335128,
#     'min_db': 13.171861719243129,
#     'mean_db': 22.63570698034438,
#     'HNR': 6.098875546044294,
#     'VADER_neg': 0.024,
#     'VADER_neu': 0.84,
#     'VADER_pos': 0.136,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 2.455157995223999,
#     'finBERT_neg': -1.917159914970398,
#     'finBERT_neu': -0.03085341304540634}},
#   {'Motorola Solutions Inc.': {'minimum_pitch': 150.45636,
#     'maximum_pitch': 3392.0671,
#     'median_f0': [[187.02466318991742]],
#     'number_of_pulses': 942,
#     'jitter_local': 0.08117855785891387,
#     'jitter_local_absolute': 0.00040072161310311546,
#     'jitter_rap': 0.04451718283282799,
#     'jitter_ppq5': 0.043741035025534676,
#     'jitter_ddp': 0.13355154849848397,
#     'max_db': 63.987282886597455,
#     'min_db': 20.077589827248797,
#     'mean_db': 34.00669526279843,
#     'HNR': 7.130321935830984,
#     'VADER_neg': 0.028,
#     'VADER_neu': 0.89,
#     'VADER_pos': 0.082,
#     'VADER_compound': 0.9973,
#     'finBERT_pos': 1.4178225994110107,
#     'finBERT_neg': 0.3393269181251526,
#     'finBERT_neu': -2.100641965866089}},
#   {'Noble Energy Inc': {'minimum_pitch': 197.1082,
#     'maximum_pitch': 3326.2898,
#     'median_f0': [[121.40883977900552]],
#     'number_of_pulses': 1502,
#     'jitter_local': 0.08903050216855338,
#     'jitter_local_absolute': 0.00043314109165277397,
#     'jitter_rap': 0.047666020608351574,
#     'jitter_ppq5': 0.05631506863905911,
#     'jitter_ddp': 0.14299806182505473,
#     'max_db': 51.40200372274115,
#     'min_db': 16.627616563502347,
#     'mean_db': 28.397617014408187,
#     'HNR': 5.012504611937301,
#     'VADER_neg': 0.019,
#     'VADER_neu': 0.857,
#     'VADER_pos': 0.124,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 2.1970643997192383,
#     'finBERT_neg': -2.101253032684326,
#     'finBERT_neu': 0.3407726585865021}}],
#  '20170202': [{'CIGNA Corp.': {'minimum_pitch': 179.82341,
#     'maximum_pitch': 1829.1207,
#     'median_f0': [[133.9939024390244]],
#     'number_of_pulses': 496,
#     'jitter_local': 0.0577599240217207,
#     'jitter_local_absolute': 0.0003796595211268925,
#     'jitter_rap': 0.03027778182812205,
#     'jitter_ppq5': 0.028226230188151222,
#     'jitter_ddp': 0.09083334548436615,
#     'max_db': 64.49811116003951,
#     'min_db': 21.77752722209613,
#     'mean_db': 40.439892673220854,
#     'HNR': 8.971603573966368,
#     'VADER_neg': 0.019,
#     'VADER_neu': 0.798,
#     'VADER_pos': 0.183,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 2.214669942855835,
#     'finBERT_neg': -2.276027202606201,
#     'finBERT_neu': 0.2691080868244171}},
#   {'Polo Ralph Lauren Corp.': {'minimum_pitch': 0.0,
#     'maximum_pitch': 3178.135,
#     'median_f0': [[217.5742574257426]],
#     'number_of_pulses': 2150,
#     'jitter_local': 0.046492288632054325,
#     'jitter_local_absolute': 0.00021069282930597958,
#     'jitter_rap': 0.02469052549183717,
#     'jitter_ppq5': 0.024518840500723494,
#     'jitter_ddp': 0.0740715764755115,
#     'max_db': 72.98541914742759,
#     'min_db': 22.527599837234177,
#     'mean_db': 36.49499831171598,
#     'HNR': 11.031729589617097,
#     'VADER_neg': 0.034,
#     'VADER_neu': 0.839,
#     'VADER_pos': 0.126,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 2.0972225666046143,
#     'finBERT_neg': -1.865148663520813,
#     'finBERT_neu': -0.1401606947183609}},
#   {'Parker-Hannifin': {'minimum_pitch': 181.29802,
#     'maximum_pitch': 3148.9539,
#     'median_f0': [[195.33719184576483]],
#     'number_of_pulses': 75,
#     'jitter_local': 0.03870020194602868,
#     'jitter_local_absolute': 0.00018978137132669073,
#     'jitter_rap': 0.018546956714531732,
#     'jitter_ppq5': 0.015530013058944178,
#     'jitter_ddp': 0.0556408701435952,
#     'max_db': 110.4120359557259,
#     'min_db': 16.32357200900404,
#     'mean_db': 49.59283137487482,
#     'HNR': 6.561708338490638,
#     'VADER_neg': 0.015,
#     'VADER_neu': 0.799,
#     'VADER_pos': 0.186,
#     'VADER_compound': 0.9997,
#     'finBERT_pos': 1.8768095970153809,
#     'finBERT_neg': -1.8305171728134155,
#     'finBERT_neu': -0.035372212529182434}},
#   {'Estee Lauder Cos.': {'minimum_pitch': 0.0,
#     'maximum_pitch': 3674.8354,
#     'median_f0': [[348.8095238095238]],
#     'number_of_pulses': 2137,
#     'jitter_local': 0.09939785762127239,
#     'jitter_local_absolute': 0.000323765890169087,
#     'jitter_rap': 0.050281187192746865,
#     'jitter_ppq5': 0.06121487323342992,
#     'jitter_ddp': 0.15084356157824058,
#     'max_db': 56.38809292951279,
#     'min_db': 12.643082552124078,
#     'mean_db': 26.688812656278,
#     'HNR': 3.86715444212393,
#     'VADER_neg': 0.012,
#     'VADER_neu': 0.765,
#     'VADER_pos': 0.223,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 2.4504494667053223,
#     'finBERT_neg': -2.087129592895508,
#     'finBERT_neu': 0.13923437893390656}},
#   {'International Paper': {'minimum_pitch': 0.0,
#     'maximum_pitch': 3133.3381,
#     'median_f0': [[366.25]],
#     'number_of_pulses': 1594,
#     'jitter_local': 0.09136122509458014,
#     'jitter_local_absolute': 0.0003089391394767659,
#     'jitter_rap': 0.04628971832675644,
#     'jitter_ppq5': 0.05864535341049706,
#     'jitter_ddp': 0.13886915498026933,
#     'max_db': 87.35699176197271,
#     'min_db': 21.509829922657815,
#     'mean_db': 44.7632382276192,
#     'HNR': 6.2381783801104564,
#     'VADER_neg': 0.038,
#     'VADER_neu': 0.849,
#     'VADER_pos': 0.113,
#     'VADER_compound': 0.9998,
#     'finBERT_pos': 1.3388726711273193,
#     'finBERT_neg': -1.276662826538086,
#     'finBERT_neu': -0.42467397451400757}},
#   {'Snap-On Inc.': {'minimum_pitch': 253.31223,
#     'maximum_pitch': 3279.5142,
#     'median_f0': [[189.43965517241378]],
#     'number_of_pulses': 1079,
#     'jitter_local': 0.0718937401773682,
#     'jitter_local_absolute': 0.00032002439796226294,
#     'jitter_rap': 0.03582363898185898,
#     'jitter_ppq5': 0.040235945314773605,
#     'jitter_ddp': 0.10747091694557695,
#     'max_db': 67.4351911209474,
#     'min_db': 25.01695962127306,
#     'mean_db': 43.47222795233825,
#     'HNR': 5.6243398038516705,
#     'VADER_neg': 0.032,
#     'VADER_neu': 0.793,
#     'VADER_pos': 0.175,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 2.412034511566162,
#     'finBERT_neg': -1.7898072004318237,
#     'finBERT_neu': -0.3300516605377197}},
#   {'Merck & Co.': {'minimum_pitch': 222.11368,
#     'maximum_pitch': 3422.6348,
#     'median_f0': [[139.08227848101265]],
#     'number_of_pulses': 1411,
#     'jitter_local': 0.06904528834091045,
#     'jitter_local_absolute': 0.0003532254111227092,
#     'jitter_rap': 0.03525118665458946,
#     'jitter_ppq5': 0.04043314993250849,
#     'jitter_ddp': 0.1057535599637684,
#     'max_db': 68.70090523984464,
#     'min_db': 16.862711764430852,
#     'mean_db': 27.38461603983522,
#     'HNR': 6.906078918000757,
#     'VADER_neg': 0.029,
#     'VADER_neu': 0.807,
#     'VADER_pos': 0.164,
#     'VADER_compound': 0.9998,
#     'finBERT_pos': 1.9946463108062744,
#     'finBERT_neg': -2.5386123657226562,
#     'finBERT_neu': 0.7504852414131165}},
#   {'Amazon.com Inc.': {'minimum_pitch': 145.4245,
#     'maximum_pitch': 3551.2688,
#     'median_f0': [[92.33193277310924]],
#     'number_of_pulses': 104,
#     'jitter_local': 0.04190259158925386,
#     'jitter_local_absolute': 0.0004370299627141826,
#     'jitter_rap': 0.020028911703040157,
#     'jitter_ppq5': 0.015271518096941166,
#     'jitter_ddp': 0.06008673510912047,
#     'max_db': 69.23067064753998,
#     'min_db': 14.98180337770739,
#     'mean_db': 36.584635873708024,
#     'HNR': 6.400825609066065,
#     'VADER_neg': 0.008,
#     'VADER_neu': 0.802,
#     'VADER_pos': 0.19,
#     'VADER_compound': 0.9998,
#     'finBERT_pos': -0.9993373155593872,
#     'finBERT_neg': -1.365885615348816,
#     'finBERT_neu': 2.2338759899139404}},
#   {'Gartner Inc': {'minimum_pitch': 162.56868,
#     'maximum_pitch': 3385.2556,
#     'median_f0': [[129.26470588235293]],
#     'number_of_pulses': 1069,
#     'jitter_local': 0.06684378281827003,
#     'jitter_local_absolute': 0.00033348647531516616,
#     'jitter_rap': 0.03590568405863468,
#     'jitter_ppq5': 0.039997102708968585,
#     'jitter_ddp': 0.10771705217590405,
#     'max_db': 73.95513035642269,
#     'min_db': 18.241468859478363,
#     'mean_db': 34.89892087494156,
#     'HNR': 8.13355875122914,
#     'VADER_neg': 0.015,
#     'VADER_neu': 0.842,
#     'VADER_pos': 0.143,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 1.6610132455825806,
#     'finBERT_neg': -2.3893020153045654,
#     'finBERT_neu': 0.7849283814430237}}],
#  '20170714': [{'JPMorgan Chase & Co.': {'minimum_pitch': 168.95836,
#     'maximum_pitch': 2673.7402,
#     'median_f0': [[180.12295081967213]],
#     'number_of_pulses': 994,
#     'jitter_local': 0.0585717951280145,
#     'jitter_local_absolute': 0.000290790314885403,
#     'jitter_rap': 0.031968118642878476,
#     'jitter_ppq5': 0.034874198385479414,
#     'jitter_ddp': 0.09590435592863543,
#     'max_db': 55.704169488295754,
#     'min_db': 17.2178963417131,
#     'mean_db': 27.8551901618918,
#     'HNR': 8.56894654458101,
#     'VADER_neg': 0.029,
#     'VADER_neu': 0.841,
#     'VADER_pos': 0.13,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 1.4320968389511108,
#     'finBERT_neg': -0.8448872566223145,
#     'finBERT_neu': -1.0391486883163452}}],
#  '20170502': [{'Martin Marietta Materials': {'minimum_pitch': 169.67908,
#     'maximum_pitch': 3120.3555,
#     'median_f0': [[115.65789473684211]],
#     'number_of_pulses': 510,
#     'jitter_local': 0.08311636515464257,
#     'jitter_local_absolute': 0.0004644382935320245,
#     'jitter_rap': 0.040720181824173564,
#     'jitter_ppq5': 0.04352693020435828,
#     'jitter_ddp': 0.1221605454725207,
#     'max_db': 65.6956006747099,
#     'min_db': 6.064111960895574,
#     'mean_db': 20.31260223099308,
#     'HNR': 5.524905251028123,
#     'VADER_neg': 0.019,
#     'VADER_neu': 0.836,
#     'VADER_pos': 0.145,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 0.9908888339996338,
#     'finBERT_neg': -1.5465725660324097,
#     'finBERT_neu': 0.160253643989563}},
#   {'Gilead Sciences': {'minimum_pitch': 148.68074,
#     'maximum_pitch': 1546.8423,
#     'median_f0': [[95.33667419536985]],
#     'number_of_pulses': 84,
#     'jitter_local': 0.061167786348179015,
#     'jitter_local_absolute': 0.0005669107247786103,
#     'jitter_rap': 0.03276590192686102,
#     'jitter_ppq5': 0.03198519155224713,
#     'jitter_ddp': 0.09829770578058306,
#     'max_db': 137.529483146038,
#     'min_db': 8.705052501849538,
#     'mean_db': 29.976865348256293,
#     'HNR': 3.6839971968373253,
#     'VADER_neg': 0.011,
#     'VADER_neu': 0.887,
#     'VADER_pos': 0.103,
#     'VADER_compound': 0.9996,
#     'finBERT_pos': -1.1979056596755981,
#     'finBERT_neg': 1.8270374536514282,
#     'finBERT_neu': -1.1362792253494263}},
#   {'Hilton Worldwide Holdings Inc': {'minimum_pitch': 146.9412,
#     'maximum_pitch': 2729.8281,
#     'median_f0': [[123.45505617977528]],
#     'number_of_pulses': 1328,
#     'jitter_local': 0.08357649165655315,
#     'jitter_local_absolute': 0.0004038007959290925,
#     'jitter_rap': 0.043619449382388854,
#     'jitter_ppq5': 0.04858714829752885,
#     'jitter_ddp': 0.13085834814716657,
#     'max_db': 58.90301535221467,
#     'min_db': 15.825827347378711,
#     'mean_db': 27.731001076931197,
#     'HNR': 7.052737659265785,
#     'VADER_neg': 0.014,
#     'VADER_neu': 0.851,
#     'VADER_pos': 0.135,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 2.282011032104492,
#     'finBERT_neg': -2.2673869132995605,
#     'finBERT_neu': 0.359424352645874}},
#   {'Aetna Inc': {'minimum_pitch': 159.16977,
#     'maximum_pitch': 3448.4106,
#     'median_f0': [[97.23451327433628]],
#     'number_of_pulses': 420,
#     'jitter_local': 0.05778875276742418,
#     'jitter_local_absolute': 0.000461342051274534,
#     'jitter_rap': 0.03133762032289128,
#     'jitter_ppq5': 0.03869458945880234,
#     'jitter_ddp': 0.09401286096867384,
#     'max_db': 74.13794160930107,
#     'min_db': 16.154682824422245,
#     'mean_db': 35.75110121026646,
#     'HNR': 6.462250453736533,
#     'VADER_neg': 0.021,
#     'VADER_neu': 0.889,
#     'VADER_pos': 0.09,
#     'VADER_compound': 0.9993,
#     'finBERT_pos': 1.5134161710739136,
#     'finBERT_neg': -1.3842462301254272,
#     'finBERT_neu': -0.3833957314491272}},
#   {'DaVita Inc.': {'minimum_pitch': 150.62784,
#     'maximum_pitch': 3183.5713,
#     'median_f0': [[124.85795454545453]],
#     'number_of_pulses': 276,
#     'jitter_local': 0.0716795957982071,
#     'jitter_local_absolute': 0.00045313403407042715,
#     'jitter_rap': 0.0371748366419056,
#     'jitter_ppq5': 0.038598279489248336,
#     'jitter_ddp': 0.1115245099257168,
#     'max_db': 103.30915021505406,
#     'min_db': 20.149262900972737,
#     'mean_db': 38.868525253975335,
#     'HNR': 6.404782978783143,
#     'VADER_neg': 0.025,
#     'VADER_neu': 0.863,
#     'VADER_pos': 0.111,
#     'VADER_compound': 0.9983,
#     'finBERT_pos': -0.6160672903060913,
#     'finBERT_neg': 0.20018154382705688,
#     'finBERT_neu': -0.19078472256660461}},
#   {'Western Union Co': {'minimum_pitch': 193.5744,
#     'maximum_pitch': 2370.4473,
#     'median_f0': [[124.85795454545453]],
#     'number_of_pulses': 687,
#     'jitter_local': 0.06969179487756948,
#     'jitter_local_absolute': 0.0004893024425983874,
#     'jitter_rap': 0.036638568828538366,
#     'jitter_ppq5': 0.039603889821865156,
#     'jitter_ddp': 0.1099157064856151,
#     'max_db': 109.75873530100507,
#     'min_db': 12.990890992234954,
#     'mean_db': 28.17825643192959,
#     'HNR': 8.347025932204991,
#     'VADER_neg': 0.018,
#     'VADER_neu': 0.884,
#     'VADER_pos': 0.099,
#     'VADER_compound': 0.9998,
#     'finBERT_pos': 0.079047791659832,
#     'finBERT_neg': 0.2736895680427551,
#     'finBERT_neu': -0.9999415278434753}},
#   {'Akamai Technologies Inc': {'minimum_pitch': 147.58289,
#     'maximum_pitch': 3479.7698,
#     'median_f0': [[112.69230769230768]],
#     'number_of_pulses': 180,
#     'jitter_local': 0.09123768761200253,
#     'jitter_local_absolute': 0.0007790279851887373,
#     'jitter_rap': 0.04648646825731416,
#     'jitter_ppq5': 0.05743809689964879,
#     'jitter_ddp': 0.13945940477194246,
#     'max_db': 51.84905387487354,
#     'min_db': 12.56147470922016,
#     'mean_db': 29.669811812730277,
#     'HNR': 5.04298814921869,
#     'VADER_neg': 0.023,
#     'VADER_neu': 0.833,
#     'VADER_pos': 0.144,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 1.2886638641357422,
#     'finBERT_neg': -0.1370687037706375,
#     'finBERT_neu': -1.5062991380691528}},
#   {'Pinnacle West Capital': {'minimum_pitch': 0.0,
#     'maximum_pitch': 694.55524,
#     'median_f0': [[330.4698100407055]],
#     'number_of_pulses': 554,
#     'jitter_local': 0.10153991696011078,
#     'jitter_local_absolute': 0.0003616407383255337,
#     'jitter_rap': 0.051541507968091774,
#     'jitter_ppq5': 0.05860791966878909,
#     'jitter_ddp': 0.15462452390427533,
#     'max_db': 102.95413040421104,
#     'min_db': 14.288870020992565,
#     'mean_db': 33.8676108403468,
#     'HNR': 5.358500073764941,
#     'VADER_neg': 0.008,
#     'VADER_neu': 0.879,
#     'VADER_pos': 0.113,
#     'VADER_compound': 0.9995,
#     'finBERT_pos': 0.7590561509132385,
#     'finBERT_neg': -2.3935327529907227,
#     'finBERT_neu': 1.4346083402633667}},
#   {'Wec Energy Group Inc': {'minimum_pitch': 148.88567,
#     'maximum_pitch': 3576.206,
#     'median_f0': [[145.5298013245033]],
#     'number_of_pulses': 679,
#     'jitter_local': 0.05421953264064586,
#     'jitter_local_absolute': 0.0003468023312529164,
#     'jitter_rap': 0.027821726035548354,
#     'jitter_ppq5': 0.02911326324884784,
#     'jitter_ddp': 0.08346517810664505,
#     'max_db': 65.010933447557,
#     'min_db': 6.4980079610035695,
#     'mean_db': 27.413889677710213,
#     'HNR': 8.462625543014175,
#     'VADER_neg': 0.016,
#     'VADER_neu': 0.881,
#     'VADER_pos': 0.103,
#     'VADER_compound': 0.9998,
#     'finBERT_pos': 1.7869808673858643,
#     'finBERT_neg': -2.6402101516723633,
#     'finBERT_neu': 1.0352147817611694}},
#   {'Altria Group Inc': {'minimum_pitch': 197.54816,
#     'maximum_pitch': 3606.8665,
#     'median_f0': [[166.4868277564139]],
#     'number_of_pulses': 879,
#     'jitter_local': 0.07750747271246539,
#     'jitter_local_absolute': 0.00035478419364557144,
#     'jitter_rap': 0.04007420687393782,
#     'jitter_ppq5': 0.044143961751897325,
#     'jitter_ddp': 0.12022262062181346,
#     'max_db': 60.92724661598179,
#     'min_db': 19.40720639239922,
#     'mean_db': 31.645523288983256,
#     'HNR': 4.806723422371241,
#     'VADER_neg': 0.017,
#     'VADER_neu': 0.91,
#     'VADER_pos': 0.073,
#     'VADER_compound': 0.9893,
#     'finBERT_pos': -1.5452479124069214,
#     'finBERT_neg': 2.620974540710449,
#     'finBERT_neu': -1.6115787029266357}},
#   {'Archer-Daniels-Midland Co': {'minimum_pitch': 147.66293,
#     'maximum_pitch': 3368.4766,
#     'median_f0': [[206.34257626520895]],
#     'number_of_pulses': 327,
#     'jitter_local': 0.09548628681307907,
#     'jitter_local_absolute': 0.0003202854668903425,
#     'jitter_rap': 0.04782190786139833,
#     'jitter_ppq5': 0.055842255117012254,
#     'jitter_ddp': 0.143465723584195,
#     'max_db': 74.1470644354016,
#     'min_db': 30.98655299173119,
#     'mean_db': 58.39807097662376,
#     'HNR': 3.2245037104702723,
#     'VADER_neg': 0.016,
#     'VADER_neu': 0.851,
#     'VADER_pos': 0.133,
#     'VADER_compound': 0.9997,
#     'finBERT_pos': 1.3935810327529907,
#     'finBERT_neg': -0.18296803534030914,
#     'finBERT_neu': -1.549027919769287}},
#   {'Emerson Electric Company': {'minimum_pitch': 169.40553,
#     'maximum_pitch': 3519.786,
#     'median_f0': [[103.16901408450703]],
#     'number_of_pulses': 229,
#     'jitter_local': 0.06530898238503578,
#     'jitter_local_absolute': 0.0005969404521728354,
#     'jitter_rap': 0.032155558970957364,
#     'jitter_ppq5': 0.03448430128517883,
#     'jitter_ddp': 0.09646667691287208,
#     'max_db': 64.9157516462659,
#     'min_db': 17.545941180933646,
#     'mean_db': 33.29549162681861,
#     'HNR': 5.479662455611658,
#     'VADER_neg': 0.023,
#     'VADER_neu': 0.832,
#     'VADER_pos': 0.146,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 1.016074299812317,
#     'finBERT_neg': -0.6785486936569214,
#     'finBERT_neu': -0.8590062856674194}},
#   {'HCA Holdings': {'minimum_pitch': 292.02032,
#     'maximum_pitch': 3334.1914,
#     'median_f0': [[197.97297297297294]],
#     'number_of_pulses': 864,
#     'jitter_local': 0.06709974761693945,
#     'jitter_local_absolute': 0.00027336781044714294,
#     'jitter_rap': 0.034119973205517254,
#     'jitter_ppq5': 0.038558965513090536,
#     'jitter_ddp': 0.10235991961655176,
#     'max_db': 58.67683481357042,
#     'min_db': 6.823707117769708,
#     'mean_db': 28.90924426239728,
#     'HNR': 7.31657315430865,
#     'VADER_neg': 0.006,
#     'VADER_neu': 0.872,
#     'VADER_pos': 0.122,
#     'VADER_compound': 0.9994,
#     'finBERT_pos': 1.3552720546722412,
#     'finBERT_neg': -0.19339555501937866,
#     'finBERT_neu': -1.291514277458191}},
#   {'Hanesbrands Inc': {'minimum_pitch': 167.27643,
#     'maximum_pitch': 3191.8489,
#     'median_f0': [[115.05235602094241]],
#     'number_of_pulses': 633,
#     'jitter_local': 0.057685393267968024,
#     'jitter_local_absolute': 0.0003835393872842298,
#     'jitter_rap': 0.030667436240087952,
#     'jitter_ppq5': 0.03482612380314907,
#     'jitter_ddp': 0.09200230872026385,
#     'max_db': 51.978483035367404,
#     'min_db': 12.551461320153356,
#     'mean_db': 23.928496269893994,
#     'HNR': 7.168574278888081,
#     'VADER_neg': 0.014,
#     'VADER_neu': 0.868,
#     'VADER_pos': 0.119,
#     'VADER_compound': 0.9997,
#     'finBERT_pos': 2.228588104248047,
#     'finBERT_neg': -2.35927677154541,
#     'finBERT_neu': 0.4508455991744995}},
#   {'Merck & Co.': {'minimum_pitch': 205.00558,
#     'maximum_pitch': 3361.3877,
#     'median_f0': [[130.80357142857142]],
#     'number_of_pulses': 573,
#     'jitter_local': 0.07492747732167492,
#     'jitter_local_absolute': 0.0003909741861924637,
#     'jitter_rap': 0.04205496843973587,
#     'jitter_ppq5': 0.05037698778856338,
#     'jitter_ddp': 0.1261649053192076,
#     'max_db': 76.69534210273171,
#     'min_db': 15.378986887760535,
#     'mean_db': 34.220090655814964,
#     'HNR': 6.15282807750939,
#     'VADER_neg': 0.021,
#     'VADER_neu': 0.837,
#     'VADER_pos': 0.142,
#     'VADER_compound': 0.9998,
#     'finBERT_pos': 1.450313687324524,
#     'finBERT_neg': -0.8487786650657654,
#     'finBERT_neu': -0.9446021914482117}}],
#  '20171024': [{'Advanced Micro Devices Inc': {'minimum_pitch': 146.97313,
#     'maximum_pitch': 2490.1658,
#     'median_f0': [[106.6747572815534]],
#     'number_of_pulses': 749,
#     'jitter_local': 0.08247049756300698,
#     'jitter_local_absolute': 0.0006639741918116818,
#     'jitter_rap': 0.042917205697550254,
#     'jitter_ppq5': 0.0495002218376051,
#     'jitter_ddp': 0.12875161709265076,
#     'max_db': 51.52682074279774,
#     'min_db': 19.312812358509763,
#     'mean_db': 31.51090502463595,
#     'HNR': 5.543368209225307,
#     'VADER_neg': 0.019,
#     'VADER_neu': 0.875,
#     'VADER_pos': 0.106,
#     'VADER_compound': 0.9985,
#     'finBERT_pos': 2.407475233078003,
#     'finBERT_neg': -1.3350597620010376,
#     'finBERT_neu': -0.6643150448799133}},
#   {'Illumina Inc': {'minimum_pitch': 145.52032,
#     'maximum_pitch': 905.0643,
#     'median_f0': [[104.64285714285714]],
#     'number_of_pulses': 806,
#     'jitter_local': 0.07022960557728225,
#     'jitter_local_absolute': 0.0006420605724231437,
#     'jitter_rap': 0.03771029057649054,
#     'jitter_ppq5': 0.0412641006889558,
#     'jitter_ddp': 0.11313087172947163,
#     'max_db': 67.30438561471607,
#     'min_db': 25.02972765907139,
#     'mean_db': 40.905326862420765,
#     'HNR': 8.202565878913171,
#     'VADER_neg': 0.016,
#     'VADER_neu': 0.875,
#     'VADER_pos': 0.11,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 2.413424015045166,
#     'finBERT_neg': -2.3263559341430664,
#     'finBERT_neu': 0.33041930198669434}},
#   {'Caterpillar Inc.': {'minimum_pitch': 158.92725,
#     'maximum_pitch': 3500.5354,
#     'median_f0': [[213.3495145631068]],
#     'number_of_pulses': 340,
#     'jitter_local': 0.04783255224690114,
#     'jitter_local_absolute': 0.0002179829911407665,
#     'jitter_rap': 0.025513854497896817,
#     'jitter_ppq5': 0.024571488091604848,
#     'jitter_ddp': 0.07654156349369046,
#     'max_db': 68.45821527958549,
#     'min_db': 19.733411740028846,
#     'mean_db': 36.26735955013829,
#     'HNR': 10.093947885243612,
#     'VADER_neg': 0.028,
#     'VADER_neu': 0.771,
#     'VADER_pos': 0.202,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 1.761461615562439,
#     'finBERT_neg': -0.8948981165885925,
#     'finBERT_neu': -0.7955442667007446}},
#   {'Lockheed Martin Corp.': {'minimum_pitch': 163.97214,
#     'maximum_pitch': 3596.1409,
#     'median_f0': [[142.69480519480518]],
#     'number_of_pulses': 600,
#     'jitter_local': 0.07824023120221528,
#     'jitter_local_absolute': 0.0003085283338695268,
#     'jitter_rap': 0.040866339709945465,
#     'jitter_ppq5': 0.0484101838642456,
#     'jitter_ddp': 0.1225990191298364,
#     'max_db': 61.09362114355016,
#     'min_db': 18.42280927749268,
#     'mean_db': 36.75643146345604,
#     'HNR': 5.738167642170129,
#     'VADER_neg': 0.032,
#     'VADER_neu': 0.834,
#     'VADER_pos': 0.134,
#     'VADER_compound': 1.0,
#     'finBERT_pos': -0.036552876234054565,
#     'finBERT_neg': 0.9096753001213074,
#     'finBERT_neu': -1.7650701999664307}},
#   {'XL Group': {'minimum_pitch': 177.89377,
#     'maximum_pitch': 2335.9038,
#     'median_f0': [[123.45505617977528]],
#     'number_of_pulses': 436,
#     'jitter_local': 0.06552905942284389,
#     'jitter_local_absolute': 0.0004959097176661653,
#     'jitter_rap': 0.03551758411883018,
#     'jitter_ppq5': 0.0412285413729065,
#     'jitter_ddp': 0.10655275235649053,
#     'max_db': 61.77412096347795,
#     'min_db': 23.82901547464071,
#     'mean_db': 35.20998422570119,
#     'HNR': 6.238475338758789,
#     'VADER_neg': 0.057,
#     'VADER_neu': 0.873,
#     'VADER_pos': 0.07,
#     'VADER_compound': 0.9041,
#     'finBERT_pos': 0.02738296054303646,
#     'finBERT_neg': 0.21085312962532043,
#     'finBERT_neu': -0.9742003083229065}},
#   {'Regions Financial Corp.': {'minimum_pitch': 158.42216,
#     'maximum_pitch': 2754.484,
#     'median_f0': [[105.39628956569746]],
#     'number_of_pulses': 582,
#     'jitter_local': 0.06991265195938365,
#     'jitter_local_absolute': 0.0005091293104173575,
#     'jitter_rap': 0.03794237692670516,
#     'jitter_ppq5': 0.044108630997151475,
#     'jitter_ddp': 0.11382713078011547,
#     'max_db': 64.48313651002542,
#     'min_db': 24.21485378036026,
#     'mean_db': 40.93781397219433,
#     'HNR': 5.630300355260761,
#     'VADER_neg': 0.029,
#     'VADER_neu': 0.827,
#     'VADER_pos': 0.144,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': -0.7860419750213623,
#     'finBERT_neg': 1.9464645385742188,
#     'finBERT_neu': -1.4953755140304565}},
#   {'General Motors': {'minimum_pitch': 290.2963,
#     'maximum_pitch': 3272.7065,
#     'median_f0': [[156.9642857142857]],
#     'number_of_pulses': 89,
#     'jitter_local': 0.08993738483729202,
#     'jitter_local_absolute': 0.0004000991854875909,
#     'jitter_rap': 0.0479359941471921,
#     'jitter_ppq5': 0.05395674128175496,
#     'jitter_ddp': 0.1438079824415763,
#     'max_db': 152.0594610080213,
#     'min_db': 14.198729254955623,
#     'mean_db': 34.28614331573287,
#     'HNR': 3.7686899964763447,
#     'VADER_neg': 0.011,
#     'VADER_neu': 0.852,
#     'VADER_pos': 0.136,
#     'VADER_compound': 0.9998,
#     'finBERT_pos': 2.55062198638916,
#     'finBERT_neg': -1.7917602062225342,
#     'finBERT_neu': -0.2790411710739136}},
#   {'Texas Instruments': {'minimum_pitch': 0.0,
#     'maximum_pitch': 2710.967,
#     'median_f0': [[131.58682634730536]],
#     'number_of_pulses': 1826,
#     'jitter_local': 0.05111256693216889,
#     'jitter_local_absolute': 0.00038398383910382826,
#     'jitter_rap': 0.027928027939513163,
#     'jitter_ppq5': 0.02920261604158821,
#     'jitter_ddp': 0.0837840838185395,
#     'max_db': 73.9330508614381,
#     'min_db': 14.223819232803006,
#     'mean_db': 23.975786168670346,
#     'HNR': 6.855510449214641,
#     'VADER_neg': 0.019,
#     'VADER_neu': 0.86,
#     'VADER_pos': 0.121,
#     'VADER_compound': 0.9992,
#     'finBERT_pos': 2.4180078506469727,
#     'finBERT_neg': -1.882318377494812,
#     'finBERT_neu': -0.17124606668949127}},
#   {"McDonald's Corp.": {'minimum_pitch': 196.19969,
#     'maximum_pitch': 3462.9624,
#     'median_f0': [[119.75565751960085]],
#     'number_of_pulses': 886,
#     'jitter_local': 0.09517297474898236,
#     'jitter_local_absolute': 0.00042344188768552745,
#     'jitter_rap': 0.0517318765055279,
#     'jitter_ppq5': 0.0592326589409558,
#     'jitter_ddp': 0.1551956295165837,
#     'max_db': 54.37989692004484,
#     'min_db': 17.879598091217083,
#     'mean_db': 33.233354864822395,
#     'HNR': 4.15678335255452,
#     'VADER_neg': 0.017,
#     'VADER_neu': 0.842,
#     'VADER_pos': 0.141,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 2.292367935180664,
#     'finBERT_neg': -2.3270576000213623,
#     'finBERT_neu': 0.4084283411502838}},
#   {'PACCAR Inc.': {'minimum_pitch': 150.82812,
#     'maximum_pitch': 3275.5154,
#     'median_f0': [[144.57236842105263]],
#     'number_of_pulses': 509,
#     'jitter_local': 0.0773818390500053,
#     'jitter_local_absolute': 0.00041110973446939784,
#     'jitter_rap': 0.040235392760639505,
#     'jitter_ppq5': 0.04320727636441419,
#     'jitter_ddp': 0.12070617828191851,
#     'max_db': 66.43498827038427,
#     'min_db': 16.15392134129488,
#     'mean_db': 44.311879551539626,
#     'HNR': 4.699365317893535,
#     'VADER_neg': 0.017,
#     'VADER_neu': 0.85,
#     'VADER_pos': 0.133,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 1.8905504941940308,
#     'finBERT_neg': -1.2689101696014404,
#     'finBERT_neu': -0.6314839720726013}},
#   {'United Technologies': {'minimum_pitch': 182.86102,
#     'maximum_pitch': 3128.3276,
#     'median_f0': [[90.06147540983606]],
#     'number_of_pulses': 142,
#     'jitter_local': 0.06994426118508273,
#     'jitter_local_absolute': 0.000779126953363198,
#     'jitter_rap': 0.03591863999763347,
#     'jitter_ppq5': 0.03516104675923818,
#     'jitter_ddp': 0.1077559199929004,
#     'max_db': 98.2376881970973,
#     'min_db': 20.75003487140251,
#     'mean_db': 35.97525984685959,
#     'HNR': 4.861306901010975,
#     'VADER_neg': 0.018,
#     'VADER_neu': 0.854,
#     'VADER_pos': 0.128,
#     'VADER_compound': 0.9985,
#     'finBERT_pos': -7.880642078816891e-05,
#     'finBERT_neg': 1.4885931015014648,
#     'finBERT_neu': -2.268754720687866}}],
#  '20171031': [{'Electronic Arts': {'minimum_pitch': 245.97987,
#     'maximum_pitch': 2312.5774,
#     'median_f0': [[124.15254237288136]],
#     'number_of_pulses': 350,
#     'jitter_local': 0.07117285115699974,
#     'jitter_local_absolute': 0.00030193780986495836,
#     'jitter_rap': 0.036108970504797944,
#     'jitter_ppq5': 0.04336550358821995,
#     'jitter_ddp': 0.10832691151439383,
#     'max_db': 94.0273948477723,
#     'min_db': 18.15846525321199,
#     'mean_db': 34.0212918908683,
#     'HNR': 6.755485513618954,
#     'VADER_neg': 0.029,
#     'VADER_neu': 0.837,
#     'VADER_pos': 0.134,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 0.08780398964881897,
#     'finBERT_neg': -0.3766075372695923,
#     'finBERT_neu': -0.4158313274383545}},
#   {'The Mosaic Company': {'minimum_pitch': 188.9627,
#     'maximum_pitch': 3577.148,
#     'median_f0': [[105.65148047985576]],
#     'number_of_pulses': 140,
#     'jitter_local': 0.06344768277429591,
#     'jitter_local_absolute': 0.0004592558413210842,
#     'jitter_rap': 0.033509775365318975,
#     'jitter_ppq5': 0.030421238563315196,
#     'jitter_ddp': 0.10052932609595693,
#     'max_db': 99.33097087992141,
#     'min_db': 18.065197048464583,
#     'mean_db': 34.972119424968106,
#     'HNR': 3.4302699055252313,
#     'VADER_neg': 0.026,
#     'VADER_neu': 0.877,
#     'VADER_pos': 0.097,
#     'VADER_compound': 0.9995,
#     'finBERT_pos': 1.4513987302780151,
#     'finBERT_neg': -1.5229018926620483,
#     'finBERT_neu': -0.23001781105995178}},
#   {'American Tower Corp A': {'minimum_pitch': 224.21185,
#     'maximum_pitch': 3743.58,
#     'median_f0': [[135.64814814814815]],
#     'number_of_pulses': 1491,
#     'jitter_local': 0.08943319677253057,
#     'jitter_local_absolute': 0.000381624249826148,
#     'jitter_rap': 0.04813687907298862,
#     'jitter_ppq5': 0.05652636046327724,
#     'jitter_ddp': 0.14441063721896585,
#     'max_db': 63.767555669686644,
#     'min_db': 25.001840332223754,
#     'mean_db': 38.719168484939075,
#     'HNR': 4.483799166272722,
#     'VADER_neg': 0.013,
#     'VADER_neu': 0.881,
#     'VADER_pos': 0.106,
#     'VADER_compound': 0.9998,
#     'finBERT_pos': 2.3815793991088867,
#     'finBERT_neg': -2.143303394317627,
#     'finBERT_neu': 0.08883751928806305}},
#   {'Ecolab Inc.': {'minimum_pitch': 215.67305,
#     'maximum_pitch': 3439.8904,
#     'median_f0': [[136.06941568898088]],
#     'number_of_pulses': 496,
#     'jitter_local': 0.07278690959500879,
#     'jitter_local_absolute': 0.00033673726297898043,
#     'jitter_rap': 0.034858628392473084,
#     'jitter_ppq5': 0.033834184431274686,
#     'jitter_ddp': 0.10457588517741925,
#     'max_db': 66.56431170148255,
#     'min_db': 10.125114432324953,
#     'mean_db': 26.29126045356083,
#     'HNR': 5.776941757792296,
#     'VADER_neg': 0.029,
#     'VADER_neu': 0.785,
#     'VADER_pos': 0.186,
#     'VADER_compound': 0.999,
#     'finBERT_pos': 0.49359360337257385,
#     'finBERT_neg': -0.4590156078338623,
#     'finBERT_neu': -0.6917653679847717}},
#   {'Kellogg Co.': {'minimum_pitch': 154.02574,
#     'maximum_pitch': 3733.7385,
#     'median_f0': [[135.64814814814815]],
#     'number_of_pulses': 1918,
#     'jitter_local': 0.09376622381807252,
#     'jitter_local_absolute': 0.00039259775182955636,
#     'jitter_rap': 0.04849550799274824,
#     'jitter_ppq5': 0.059998542624189743,
#     'jitter_ddp': 0.14548652397824471,
#     'max_db': 61.91230559943999,
#     'min_db': 13.478982818049419,
#     'mean_db': 28.78557094379933,
#     'HNR': 4.702517201844664,
#     'VADER_neg': 0.014,
#     'VADER_neu': 0.794,
#     'VADER_pos': 0.192,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 1.7489957809448242,
#     'finBERT_neg': -1.1707708835601807,
#     'finBERT_neu': -0.6896664500236511}},
#   {'Aetna Inc': {'minimum_pitch': 166.30627,
#     'maximum_pitch': 3570.0325,
#     'median_f0': [[128.50877192982455]],
#     'number_of_pulses': 1190,
#     'jitter_local': 0.055884617005092625,
#     'jitter_local_absolute': 0.0003705951548590902,
#     'jitter_rap': 0.030094395097740603,
#     'jitter_ppq5': 0.03149096283484906,
#     'jitter_ddp': 0.09028318529322181,
#     'max_db': 72.71837445769864,
#     'min_db': 26.42610837515828,
#     'mean_db': 38.38917197447988,
#     'HNR': 8.28353206008409,
#     'VADER_neg': 0.01,
#     'VADER_neu': 0.886,
#     'VADER_pos': 0.103,
#     'VADER_compound': 0.9998,
#     'finBERT_pos': 1.0549741983413696,
#     'finBERT_neg': -0.84671550989151,
#     'finBERT_neu': -0.6023197174072266}},
#   {'Archer-Daniels-Midland Co': {'minimum_pitch': 146.56403,
#     'maximum_pitch': 3421.6406,
#     'median_f0': [[127.02312138728323]],
#     'number_of_pulses': 1437,
#     'jitter_local': 0.07689524266672738,
#     'jitter_local_absolute': 0.0003762042504569412,
#     'jitter_rap': 0.04134004403055304,
#     'jitter_ppq5': 0.04352717410194444,
#     'jitter_ddp': 0.12402013209165912,
#     'max_db': 59.31702443278115,
#     'min_db': 21.73162311407141,
#     'mean_db': 35.018968853857956,
#     'HNR': 6.321655209662047,
#     'VADER_neg': 0.026,
#     'VADER_neu': 0.865,
#     'VADER_pos': 0.108,
#     'VADER_compound': 0.9995,
#     'finBERT_pos': -0.5890124440193176,
#     'finBERT_neg': 1.1860020160675049,
#     'finBERT_neu': -1.467537522315979}}],
#  '20170503': [{'NiSource Inc.': {'minimum_pitch': 170.1669,
#     'maximum_pitch': 3485.615,
#     'median_f0': [[108.7871287128713]],
#     'number_of_pulses': 1102,
#     'jitter_local': 0.08093238067791568,
#     'jitter_local_absolute': 0.0005634182654107651,
#     'jitter_rap': 0.0430550067198343,
#     'jitter_ppq5': 0.04586335428441001,
#     'jitter_ddp': 0.1291650201595029,
#     'max_db': 51.95047112196991,
#     'min_db': 11.131403907485318,
#     'mean_db': 26.99085799632785,
#     'HNR': 4.522755366064301,
#     'VADER_neg': 0.019,
#     'VADER_neu': 0.899,
#     'VADER_pos': 0.082,
#     'VADER_compound': 0.9933,
#     'finBERT_pos': 1.5781409740447998,
#     'finBERT_neg': -1.5931977033615112,
#     'finBERT_neu': 0.04484925419092178}},
#   {'Garmin Ltd.': {'minimum_pitch': 161.2283,
#     'maximum_pitch': 1754.5873,
#     'median_f0': [[121.40883977900552]],
#     'number_of_pulses': 63,
#     'jitter_local': 0.09201269387207732,
#     'jitter_local_absolute': 0.0007640212229324042,
#     'jitter_rap': 0.053550766743297826,
#     'jitter_ppq5': 0.0640867712570207,
#     'jitter_ddp': 0.16065230022989346,
#     'max_db': 162.94552750548706,
#     'min_db': 13.006165606273703,
#     'mean_db': 37.939257109778026,
#     'HNR': 3.9970585769627047,
#     'VADER_neg': 0.028,
#     'VADER_neu': 0.758,
#     'VADER_pos': 0.214,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 2.452176332473755,
#     'finBERT_neg': -1.8296481370925903,
#     'finBERT_neu': -0.15779539942741394}},
#   {'The Clorox Company': {'minimum_pitch': 151.53073,
#     'maximum_pitch': 3283.582,
#     'median_f0': [[120.74175824175823]],
#     'number_of_pulses': 576,
#     'jitter_local': 0.0679320979259864,
#     'jitter_local_absolute': 0.0004841024636953465,
#     'jitter_rap': 0.03600689401019126,
#     'jitter_ppq5': 0.03841270207955349,
#     'jitter_ddp': 0.10802068203057379,
#     'max_db': 66.8231388942988,
#     'min_db': 14.469972251240781,
#     'mean_db': 36.916575534986606,
#     'HNR': 6.279226009058764,
#     'VADER_neg': 0.019,
#     'VADER_neu': 0.782,
#     'VADER_pos': 0.198,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 0.63438481092453,
#     'finBERT_neg': -2.518282890319824,
#     'finBERT_neu': 1.7432869672775269}},
#   {'Estee Lauder Cos.': {'minimum_pitch': 147.22963,
#     'maximum_pitch': 3666.228,
#     'median_f0': [[327.98507462686564]],
#     'number_of_pulses': 2059,
#     'jitter_local': 0.08807519055276253,
#     'jitter_local_absolute': 0.0003531458532127256,
#     'jitter_rap': 0.045474742473273926,
#     'jitter_ppq5': 0.04961316549254139,
#     'jitter_ddp': 0.13642422741982177,
#     'max_db': 57.6418473568162,
#     'min_db': 11.567039340954024,
#     'mean_db': 28.227219782032712,
#     'HNR': 4.141021932622822,
#     'VADER_neg': 0.007,
#     'VADER_neu': 0.821,
#     'VADER_pos': 0.172,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 2.5251712799072266,
#     'finBERT_neg': -1.8502509593963623,
#     'finBERT_neu': -0.22079740464687347}},
#   {'Humana Inc.': {'minimum_pitch': 146.83469,
#     'maximum_pitch': 3453.1985,
#     'median_f0': [[159.2391304347826]],
#     'number_of_pulses': 920,
#     'jitter_local': 0.06779604208444087,
#     'jitter_local_absolute': 0.0003327892369978829,
#     'jitter_rap': 0.03633515550561711,
#     'jitter_ppq5': 0.03889586155311344,
#     'jitter_ddp': 0.10900546651685133,
#     'max_db': 48.18971443706822,
#     'min_db': 8.103707935972558,
#     'mean_db': 23.873355806399644,
#     'HNR': 7.717806691815869,
#     'VADER_neg': 0.023,
#     'VADER_neu': 0.862,
#     'VADER_pos': 0.115,
#     'VADER_compound': 0.9998,
#     'finBERT_pos': 0.504427433013916,
#     'finBERT_neg': -0.9819391965866089,
#     'finBERT_neu': -0.11352485418319702}}],
#  '20170822': [{'Salesforce.com': {'minimum_pitch': 204.15327,
#     'maximum_pitch': 3549.546,
#     'median_f0': [[414.6226415094339]],
#     'number_of_pulses': 1433,
#     'jitter_local': 0.09833726576420602,
#     'jitter_local_absolute': 0.00030215979582064845,
#     'jitter_rap': 0.05286990288628214,
#     'jitter_ppq5': 0.06320837290948156,
#     'jitter_ddp': 0.15860970865884644,
#     'max_db': 59.853442629387,
#     'min_db': 12.327072910546935,
#     'mean_db': 27.57374631825368,
#     'HNR': 7.454455100221527,
#     'VADER_neg': 0.019,
#     'VADER_neu': 0.833,
#     'VADER_pos': 0.148,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 0.4399605989456177,
#     'finBERT_neg': -1.6288679838180542,
#     'finBERT_neu': 0.8917704820632935}},
#   {'Coty, Inc': {'minimum_pitch': 146.21219,
#     'maximum_pitch': 3581.3455,
#     'median_f0': [[138.2075471698113]],
#     'number_of_pulses': 1253,
#     'jitter_local': 0.08588353730772981,
#     'jitter_local_absolute': 0.0004540303689389663,
#     'jitter_rap': 0.045688620828976345,
#     'jitter_ppq5': 0.051053105504223414,
#     'jitter_ddp': 0.13706586248692904,
#     'max_db': 62.93212901185626,
#     'min_db': 6.243483809450272,
#     'mean_db': 24.997151605175542,
#     'HNR': 5.208338698146476,
#     'VADER_neg': 0.015,
#     'VADER_neu': 0.803,
#     'VADER_pos': 0.182,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 1.7883282899856567,
#     'finBERT_neg': -0.6009392738342285,
#     'finBERT_neu': -1.3999593257904053}}],
#  '20170131': [{'Lilly (Eli) & Co.': {'minimum_pitch': 150.51637,
#     'maximum_pitch': 3339.3352,
#     'median_f0': [[145.5298013245033]],
#     'number_of_pulses': 1102,
#     'jitter_local': 0.08475302076632878,
#     'jitter_local_absolute': 0.00047543556213257564,
#     'jitter_rap': 0.04464572047101881,
#     'jitter_ppq5': 0.051413908552119074,
#     'jitter_ddp': 0.13393716141305642,
#     'max_db': 66.21411718366849,
#     'min_db': 19.68458010566273,
#     'mean_db': 30.839542125963487,
#     'HNR': 6.425522022198461,
#     'VADER_neg': 0.026,
#     'VADER_neu': 0.829,
#     'VADER_pos': 0.145,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 0.005987903103232384,
#     'finBERT_neg': -1.8572992086410522,
#     'finBERT_neu': 1.4677265882492065}},
#   {'Align Technology': {'minimum_pitch': 160.75044,
#     'maximum_pitch': 2366.7603,
#     'median_f0': [[133.9939024390244]],
#     'number_of_pulses': 770,
#     'jitter_local': 0.07846732100675831,
#     'jitter_local_absolute': 0.00043685693618383207,
#     'jitter_rap': 0.043294217489105856,
#     'jitter_ppq5': 0.04596576560900289,
#     'jitter_ddp': 0.12988265246731756,
#     'max_db': 59.65087373324885,
#     'min_db': 25.94510351348861,
#     'mean_db': 41.227482030041536,
#     'HNR': 6.358101112084268,
#     'VADER_neg': 0.023,
#     'VADER_neu': 0.876,
#     'VADER_pos': 0.1,
#     'VADER_compound': 0.9996,
#     'finBERT_pos': 0.8229905962944031,
#     'finBERT_neg': 0.8343772888183594,
#     'finBERT_neu': -2.281101703643799}},
#   {'Mastercard Inc.': {'minimum_pitch': 216.53969,
#     'maximum_pitch': 3477.5986,
#     'median_f0': [[194.46902654867256]],
#     'number_of_pulses': 642,
#     'jitter_local': 0.07221421177166547,
#     'jitter_local_absolute': 0.0002672200370375257,
#     'jitter_rap': 0.038722626978424844,
#     'jitter_ppq5': 0.042457985936247375,
#     'jitter_ddp': 0.11616788093527453,
#     'max_db': 61.07368226055491,
#     'min_db': 11.549903492226306,
#     'mean_db': 33.521885190731375,
#     'HNR': 7.412487637655338,
#     'VADER_neg': 0.021,
#     'VADER_neu': 0.812,
#     'VADER_pos': 0.167,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 1.3244694471359253,
#     'finBERT_neg': -1.5717862844467163,
#     'finBERT_neu': -0.3234747052192688}},
#   {'Valero Energy': {'minimum_pitch': 306.43002,
#     'maximum_pitch': 3593.5564,
#     'median_f0': [[392.4107142857142]],
#     'number_of_pulses': 565,
#     'jitter_local': 0.1087512566058783,
#     'jitter_local_absolute': 0.00036917229120450633,
#     'jitter_rap': 0.05767491537331761,
#     'jitter_ppq5': 0.06331334939965208,
#     'jitter_ddp': 0.17302474611995283,
#     'max_db': 66.91062758947194,
#     'min_db': 26.3553066119486,
#     'mean_db': 36.291676733269135,
#     'HNR': 2.1881547561315324,
#     'VADER_neg': 0.031,
#     'VADER_neu': 0.817,
#     'VADER_pos': 0.152,
# ...
#     'finBERT_neg': -2.6025876998901367,
#     'finBERT_neu': 0.889285147190094}}],
#  '20170620': [{'Lennar Corp.': {'minimum_pitch': 191.24876,
#     'maximum_pitch': 3267.2395,
#     'median_f0': [[134.4049266796349]],
#     'number_of_pulses': 793,
#     'jitter_local': 0.056479488901043845,
#     'jitter_local_absolute': 0.00032854723797154356,
#     'jitter_rap': 0.029788408011581485,
#     'jitter_ppq5': 0.030762589739003064,
#     'jitter_ddp': 0.08936522403474445,
#     'max_db': 63.46512958331551,
#     'min_db': 12.104663581365198,
#     'mean_db': 24.49439761252453,
#     'HNR': 9.438445318992022,
#     'VADER_neg': 0.011,
#     'VADER_neu': 0.861,
#     'VADER_pos': 0.128,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 1.5663961172103882,
#     'finBERT_neg': -2.010089159011841,
#     'finBERT_neu': 0.2699280083179474}}],
#  '20171107': [{'Royal Caribbean Cruises Ltd': {'minimum_pitch': 145.43553,
#     'maximum_pitch': 3471.0469,
#     'median_f0': [[119.42934782608695]],
#     'number_of_pulses': 2629,
#     'jitter_local': 0.06468595566785586,
#     'jitter_local_absolute': 0.0005101408447123163,
#     'jitter_rap': 0.033285863146746995,
#     'jitter_ppq5': 0.03608611906210259,
#     'jitter_ddp': 0.09985758944024098,
#     'max_db': 46.26961994144739,
#     'min_db': 15.886494124275083,
#     'mean_db': 19.336213254342045,
#     'HNR': 5.967582088406481,
#     'VADER_neg': 0.032,
#     'VADER_neu': 0.81,
#     'VADER_pos': 0.158,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 1.4472792148590088,
#     'finBERT_neg': -1.9604319334030151,
#     'finBERT_neu': 0.47041749954223633}},
#   {'Nektar Therapeutics': {'minimum_pitch': 146.75264,
#     'maximum_pitch': 3492.2168,
#     'median_f0': [[101.03501669978438]],
#     'number_of_pulses': 177,
#     'jitter_local': 0.0684215189424812,
#     'jitter_local_absolute': 0.00041011315773298226,
#     'jitter_rap': 0.03205194465117511,
#     'jitter_ppq5': 0.03591606538686914,
#     'jitter_ddp': 0.09615583395352534,
#     'max_db': 70.25508765047752,
#     'min_db': 6.790368011733047,
#     'mean_db': 27.360582221541414,
#     'HNR': 5.566868083285461,
#     'VADER_neg': 0.082,
#     'VADER_neu': 0.79,
#     'VADER_pos': 0.128,
#     'VADER_compound': 0.999,
#     'finBERT_pos': 1.5321345329284668,
#     'finBERT_neg': -2.620718002319336,
#     'finBERT_neu': 1.1011327505111694}}],
#  '20170914': [{'Oracle Corp.': {'minimum_pitch': 149.20813,
#     'maximum_pitch': 2900.5388,
#     'median_f0': [[184.6638655462185]],
#     'number_of_pulses': 432,
#     'jitter_local': 0.056213859724216,
#     'jitter_local_absolute': 0.00027071352456718267,
#     'jitter_rap': 0.03226310344200952,
#     'jitter_ppq5': 0.03316627383680383,
#     'jitter_ddp': 0.09678931032602855,
#     'max_db': 69.66569008327897,
#     'min_db': 14.573164226799014,
#     'mean_db': 41.415040182217155,
#     'HNR': 6.76475377949362,
#     'VADER_neg': 0.018,
#     'VADER_neu': 0.896,
#     'VADER_pos': 0.086,
#     'VADER_compound': 0.9985,
#     'finBERT_pos': 1.3470112085342407,
#     'finBERT_neg': 0.3234100341796875,
#     'finBERT_neu': -2.1192808151245117}}],
#  '20170728': [{'AbbVie Inc.': {'minimum_pitch': 172.34752,
#     'maximum_pitch': 3734.471,
#     'median_f0': [[146.5]],
#     'number_of_pulses': 3253,
#     'jitter_local': 0.07316836201000346,
#     'jitter_local_absolute': 0.000409192635909394,
#     'jitter_rap': 0.03965169223151574,
#     'jitter_ppq5': 0.04454001068522452,
#     'jitter_ddp': 0.11895507669454722,
#     'max_db': 53.0916052325949,
#     'min_db': 17.387756136454215,
#     'mean_db': 25.983212807061303,
#     'HNR': 6.589843904526589,
#     'VADER_neg': 0.028,
#     'VADER_neu': 0.867,
#     'VADER_pos': 0.106,
#     'VADER_compound': 0.9969,
#     'finBERT_pos': 0.7175623178482056,
#     'finBERT_neg': 0.6104907393455505,
#     'finBERT_neu': -2.141847610473633}},
#   {'Chevron Corp.': {'minimum_pitch': 0.0,
#     'maximum_pitch': 1772.4885,
#     'median_f0': [[85.50583657587548]],
#     'number_of_pulses': 311,
#     'jitter_local': 0.051541479486070275,
#     'jitter_local_absolute': 0.00035092799373124015,
#     'jitter_rap': 0.024838347845234383,
#     'jitter_ppq5': 0.029083300018873996,
#     'jitter_ddp': 0.07451504353570315,
#     'max_db': 72.89845230526247,
#     'min_db': 21.000306279629214,
#     'mean_db': 37.73325846356013,
#     'HNR': 5.6000704180299055,
#     'VADER_neg': 0.016,
#     'VADER_neu': 0.843,
#     'VADER_pos': 0.141,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 1.4771138429641724,
#     'finBERT_neg': -1.3263237476348877,
#     'finBERT_neu': -0.21428059041500092}}],
#  '20170118': [{'Citigroup Inc.': {'minimum_pitch': 149.53107,
#     'maximum_pitch': 2549.748,
#     'median_f0': [[137.34375]],
#     'number_of_pulses': 80,
#     'jitter_local': 0.05838325652841895,
#     'jitter_local_absolute': 0.00041636443230963494,
#     'jitter_rap': 0.024520255863538124,
#     'jitter_ppq5': 0.030037788018434312,
#     'jitter_ddp': 0.07356076759061438,
#     'max_db': 101.43000480757236,
#     'min_db': 19.965819867245802,
#     'mean_db': 48.683715486355034,
#     'HNR': 9.38426889149892,
#     'VADER_neg': 0.018,
#     'VADER_neu': 0.845,
#     'VADER_pos': 0.137,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 1.1064503192901611,
#     'finBERT_neg': 0.32802024483680725,
#     'finBERT_neu': -1.8058161735534668}}],
#  '20171115': [{'Cisco Systems': {'minimum_pitch': 228.42935,
#     'maximum_pitch': 3264.7969,
#     'median_f0': [[129.64714584058476]],
#     'number_of_pulses': 128,
#     'jitter_local': 0.05800671191595445,
#     'jitter_local_absolute': 0.0004212434944795854,
#     'jitter_rap': 0.03059987382948884,
#     'jitter_ppq5': 0.0277458792961469,
#     'jitter_ddp': 0.09179962148846652,
#     'max_db': 238.67069866573394,
#     'min_db': 22.5949790399738,
#     'mean_db': 38.06574328979446,
#     'HNR': 6.557378623654474,
#     'VADER_neg': 0.014,
#     'VADER_neu': 0.848,
#     'VADER_pos': 0.138,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 2.2361536026000977,
#     'finBERT_neg': -2.50605845451355,
#     'finBERT_neu': 0.6900157928466797}},
#   {'Target Corp.': {'minimum_pitch': 150.8582,
#     'maximum_pitch': 3253.096,
#     'median_f0': [[155.85106382978722]],
#     'number_of_pulses': 317,
#     'jitter_local': 0.04412153439478843,
#     'jitter_local_absolute': 0.0002447397240657815,
#     'jitter_rap': 0.023382298425331228,
#     'jitter_ppq5': 0.02522107250511571,
#     'jitter_ddp': 0.07014689527599369,
#     'max_db': 68.71628110663796,
#     'min_db': 21.731566166433645,
#     'mean_db': 39.299692539765445,
#     'HNR': 7.157206071422609,
#     'VADER_neg': 0.012,
#     'VADER_neu': 0.863,
#     'VADER_pos': 0.125,
#     'VADER_compound': 0.9998,
#     'finBERT_pos': 1.9370366334915161,
#     'finBERT_neg': -2.5283894538879395,
#     'finBERT_neu': 0.8437891006469727}},
#   {'NetApp': {'minimum_pitch': 228.73857,
#     'maximum_pitch': 3414.6267,
#     'median_f0': [[196.2053571428571]],
#     'number_of_pulses': 829,
#     'jitter_local': 0.09381641635422547,
#     'jitter_local_absolute': 0.00044833334936141684,
#     'jitter_rap': 0.05104957077473379,
#     'jitter_ppq5': 0.05345541951254883,
#     'jitter_ddp': 0.15314871232420138,
#     'max_db': 49.281803989301274,
#     'min_db': 2.865656221737879,
#     'mean_db': 14.626709213979916,
#     'HNR': 6.344166586672615,
#     'VADER_neg': 0.009,
#     'VADER_neu': 0.827,
#     'VADER_pos': 0.164,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 2.223785161972046,
#     'finBERT_neg': -2.3316919803619385,
#     'finBERT_neu': 0.47019243240356445}}],
#  '20170517': [{'Synopsys Inc.': {'minimum_pitch': 149.83797,
#     'maximum_pitch': 3803.5293,
#     'median_f0': [[128.50877192982455]],
#     'number_of_pulses': 516,
#     'jitter_local': 0.07487057825148519,
#     'jitter_local_absolute': 0.0005027998022197381,
#     'jitter_rap': 0.036910353026263415,
#     'jitter_ppq5': 0.04045542987960261,
#     'jitter_ddp': 0.11073105907879024,
#     'max_db': 204.5214498493085,
#     'min_db': 11.072015205499962,
#     'mean_db': 23.48883666529374,
#     'HNR': 4.886831616596149,
#     'VADER_neg': 0.022,
#     'VADER_neu': 0.812,
#     'VADER_pos': 0.167,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 1.9955236911773682,
#     'finBERT_neg': -2.552825450897217,
#     'finBERT_neu': 0.8149592280387878}}],
#  '20170817': [{'Ross Stores': {'minimum_pitch': 154.6733,
#     'maximum_pitch': 3529.02,
#     'median_f0': [[103.16901408450703]],
#     'number_of_pulses': 1020,
#     'jitter_local': 0.05669339596111756,
#     'jitter_local_absolute': 0.0004765846060756517,
#     'jitter_rap': 0.02889016674415657,
#     'jitter_ppq5': 0.03048630238217524,
#     'jitter_ddp': 0.08667050023246972,
#     'max_db': 70.16355900836454,
#     'min_db': 11.476601037491127,
#     'mean_db': 27.571103454450945,
#     'HNR': 7.466838026000049,
#     'VADER_neg': 0.007,
#     'VADER_neu': 0.865,
#     'VADER_pos': 0.128,
#     'VADER_compound': 0.9993,
#     'finBERT_pos': 2.05477237701416,
#     'finBERT_neg': -1.2506738901138306,
#     'finBERT_neu': -0.7110310792922974}}],
#  '20170721': [{'Regions Financial Corp.': {'minimum_pitch': 152.97508,
#     'maximum_pitch': 2682.2754,
#     'median_f0': [[175.8]],
#     'number_of_pulses': 79,
#     'jitter_local': 0.06603981812563492,
#     'jitter_local_absolute': 0.0002692314389485127,
#     'jitter_rap': 0.032159497236968884,
#     'jitter_ppq5': 0.034459628017849624,
#     'jitter_ddp': 0.09647849171090665,
#     'max_db': 67.76556700592563,
#     'min_db': 20.320126103729123,
#     'mean_db': 58.40762940307481,
#     'HNR': 4.606527806173833,
#     'VADER_neg': 0.026,
#     'VADER_neu': 0.805,
#     'VADER_pos': 0.168,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 0.8842745423316956,
#     'finBERT_neg': 0.01867515966296196,
#     'finBERT_neu': -1.3322043418884277}}],
#  '20170222': [{'HP Inc.': {'minimum_pitch': 0.0,
#     'maximum_pitch': 3575.854,
#     'median_f0': [[95.96069868995633]],
#     'number_of_pulses': 1294,
#     'jitter_local': 0.0821663763933018,
#     'jitter_local_absolute': 0.0007293103230348466,
#     'jitter_rap': 0.041793384270731336,
#     'jitter_ppq5': 0.04694739672674184,
#     'jitter_ddp': 0.125380152812194,
#     'max_db': 61.20931900888151,
#     'min_db': 21.923518684865535,
#     'mean_db': 29.39844861909018,
#     'HNR': 4.783778715159749,
#     'VADER_neg': 0.018,
#     'VADER_neu': 0.808,
#     'VADER_pos': 0.174,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 2.4995357990264893,
#     'finBERT_neg': -1.939818263053894,
#     'finBERT_neu': -0.04669796675443649}}],
#  '20170321': [{'Nike': {'minimum_pitch': 197.38936,
#     'maximum_pitch': 3598.24,
#     'median_f0': [[136.49068322981364]],
#     'number_of_pulses': 1597,
#     'jitter_local': 0.07074886809508665,
#     'jitter_local_absolute': 0.0004486785893766227,
#     'jitter_rap': 0.03694985368456527,
#     'jitter_ppq5': 0.038188191907318696,
#     'jitter_ddp': 0.11084956105369581,
#     'max_db': 56.965132265188494,
#     'min_db': 21.47862279699991,
#     'mean_db': 32.143097989937274,
#     'HNR': 4.90020033173819,
#     'VADER_neg': 0.029,
#     'VADER_neu': 0.782,
#     'VADER_pos': 0.189,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 2.1903841495513916,
#     'finBERT_neg': -1.8581435680389404,
#     'finBERT_neu': -0.08911190927028656}}],
#  '20170511': [{"Kohl's Corp.": {'minimum_pitch': 195.95702,
#     'maximum_pitch': 2127.007,
#     'median_f0': [[158.0935251798561]],
#     'number_of_pulses': 687,
#     'jitter_local': 0.04547419608861311,
#     'jitter_local_absolute': 0.00024812354640267625,
#     'jitter_rap': 0.024615433608635752,
#     'jitter_ppq5': 0.02249498102921763,
#     'jitter_ddp': 0.07384630082590726,
#     'max_db': 66.93317870070949,
#     'min_db': 20.439314045228873,
#     'mean_db': 35.110633124556244,
#     'HNR': 6.89039763176673,
#     'VADER_neg': 0.023,
#     'VADER_neu': 0.792,
#     'VADER_pos': 0.185,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 0.7345302700996399,
#     'finBERT_neg': 0.2325957715511322,
#     'finBERT_neu': -1.5778521299362183}}],
#  '20170123': [{'ResMed': {'minimum_pitch': 155.36566,
#     'maximum_pitch': 1105.5282,
#     'median_f0': [[132.37951807228916]],
#     'number_of_pulses': 255,
#     'jitter_local': 0.05622438624413965,
#     'jitter_local_absolute': 0.00040776814687708886,
#     'jitter_rap': 0.028592145510463376,
#     'jitter_ppq5': 0.031085071021056145,
#     'jitter_ddp': 0.08577643653139012,
#     'max_db': 99.60678473129067,
#     'min_db': 10.496979910286937,
#     'mean_db': 30.296870212406862,
#     'HNR': 9.505886475221569,
#     'VADER_neg': 0.018,
#     'VADER_neu': 0.8,
#     'VADER_pos': 0.182,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 2.43721079826355,
#     'finBERT_neg': -2.1751818656921387,
#     'finBERT_neu': 0.18912364542484283}}],
#  '20170621': [{'Oracle Corp.': {'minimum_pitch': 151.2834,
#     'maximum_pitch': 3063.556,
#     'median_f0': [[203.47222222222223]],
#     'number_of_pulses': 972,
#     'jitter_local': 0.054958801678372624,
#     'jitter_local_absolute': 0.00025323649115677297,
#     'jitter_rap': 0.029078634038253674,
#     'jitter_ppq5': 0.029207635074530218,
#     'jitter_ddp': 0.08723590211476102,
#     'max_db': 69.1842019244861,
#     'min_db': 16.75717515687941,
#     'mean_db': 33.8953142718817,
#     'HNR': 8.315209912349165,
#     'VADER_neg': 0.028,
#     'VADER_neu': 0.891,
#     'VADER_pos': 0.081,
#     'VADER_compound': 0.9992,
#     'finBERT_pos': 1.6140697002410889,
#     'finBERT_neg': -2.490652561187744,
#     'finBERT_neu': 0.8238735795021057}}],
#  '20171207': [{'Dollar General': {'minimum_pitch': 170.78033,
#     'maximum_pitch': 3430.1165,
#     'median_f0': [[156.9642857142857]],
#     'number_of_pulses': 3228,
#     'jitter_local': 0.05420436711767136,
#     'jitter_local_absolute': 0.0003587849095128162,
#     'jitter_rap': 0.028027147890033816,
#     'jitter_ppq5': 0.02943011282946193,
#     'jitter_ddp': 0.08408144367010145,
#     'max_db': 58.8818594512668,
#     'min_db': 23.38765451794692,
#     'mean_db': 34.66358360987077,
#     'HNR': 9.363304156117877,
#     'VADER_neg': 0.024,
#     'VADER_neu': 0.852,
#     'VADER_pos': 0.124,
#     'VADER_compound': 0.9994,
#     'finBERT_pos': 0.4086124300956726,
#     'finBERT_neg': 0.10366681963205338,
#     'finBERT_neu': -1.128463625907898}}],
#  '20170925': [{'Red Hat Inc.': {'minimum_pitch': 145.69861,
#     'maximum_pitch': 3565.067,
#     'median_f0': [[124.85795454545453]],
#     'number_of_pulses': 1184,
#     'jitter_local': 0.051597010989980735,
#     'jitter_local_absolute': 0.00034699608866920216,
#     'jitter_rap': 0.025793827199993707,
#     'jitter_ppq5': 0.027734867706541943,
#     'jitter_ddp': 0.07738148159998112,
#     'max_db': 49.53030449133011,
#     'min_db': 23.22244930284048,
#     'mean_db': 27.6906179914427,
#     'HNR': 7.054382049586506,
#     'VADER_neg': 0.007,
#     'VADER_neu': 0.845,
#     'VADER_pos': 0.147,
#     'VADER_compound': 0.9999,
#     'finBERT_pos': 2.031869411468506,
#     'finBERT_neg': -1.8168319463729858,
#     'finBERT_neu': -0.04267431050539017}}],
#  '20170711': [{'PepsiCo Inc.': {'minimum_pitch': 176.0806,
#     'maximum_pitch': 3693.8652,
#     'median_f0': [[221.96969696969694]],
#     'number_of_pulses': 856,
#     'jitter_local': 0.057222709573356234,
#     'jitter_local_absolute': 0.0002352736525434304,
#     'jitter_rap': 0.029693617928913438,
#     'jitter_ppq5': 0.03048665392680455,
#     'jitter_ddp': 0.08908085378674031,
#     'max_db': 67.87936350815974,
#     'min_db': 23.251520989601573,
#     'mean_db': 38.54223452153547,
#     'HNR': 8.836461833419342,
#     'VADER_neg': 0.016,
#     'VADER_neu': 0.803,
#     'VADER_pos': 0.18,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 2.431274890899658,
#     'finBERT_neg': -1.7177761793136597,
#     'finBERT_neu': -0.33594194054603577}}],
#  '20171004': [{'PepsiCo Inc.': {'minimum_pitch': 155.26787,
#     'maximum_pitch': 3221.4966,
#     'median_f0': [[226.5463917525773]],
#     'number_of_pulses': 441,
#     'jitter_local': 0.06623218808862863,
#     'jitter_local_absolute': 0.00028780301265743136,
#     'jitter_rap': 0.03556897796036293,
#     'jitter_ppq5': 0.035020259887246996,
#     'jitter_ddp': 0.10670693388108879,
#     'max_db': 96.83272856230829,
#     'min_db': 23.233415306363323,
#     'mean_db': 39.91745152471527,
#     'HNR': 7.897162556932276,
#     'VADER_neg': 0.021,
#     'VADER_neu': 0.829,
#     'VADER_pos': 0.15,
#     'VADER_compound': 1.0,
#     'finBERT_pos': 1.879594326019287,
#     'finBERT_neg': -0.8247131705284119,
#     'finBERT_neu': -1.1294963359832764}}]}

# %%
def compute_audio_features(audio_list, sr):
    features_dict = {}
    
    F_0 = sig.get_F_0(signal, sr)
    jitter= sig.get_Jitter(signal, sr)
    pulses = sig.get_Pulses(signal, sr)

    #Pitch analysis
    pitches, magnitudes = librosa.core.piptrack(y=signal, sr=sr)
    pitches_to_use = []
    for t in range (magnitudes.shape[1]):
        index = magnitudes[:, t].argmax()
        pitch = pitches[index, t]
        pitches_to_use.append(pitch)

    minimum_pitch = np.amin(pitches_to_use)
    features_dict ['minimum_pitch'] = minimum_pitch

    maximum_pitch = np.amax(pitches_to_use)
    features_dict ['maximum_pitch'] = maximum_pitch

    median_F0 = F_0
    features_dict ['median_f0'] = [median_F0]

    number_of_pulses = len(pulses)
    features_dict ['number_of_pulses'] = number_of_pulses
        

    #Voice analysis
        
    jitter_local = jitter['local']
    features_dict ['jitter_local'] = jitter_local
        
    jitter_local_absolute = jitter['local, absolute']
    features_dict ['jitter_local_absolute'] = jitter_local_absolute
        
    jitter_rap = jitter['rap']
    features_dict ['jitter_rap'] = jitter_rap
        
    jitter_ppq5 = jitter['ppq5']
    features_dict ['jitter_ppq5'] = jitter_ppq5
        
    jitter_ddp = jitter['ddp']
    features_dict ['jitter_ddp'] = jitter_ddp
      

    #intensity analysis
    numchunks = 100
    chunks = np.array_split(signal, numchunks)
    dbs = [-20*math.log10( math.sqrt(np.mean(chunk**2)) ) for chunk in chunks]

    mean_db = 0
    count = 0
    min_db = float('inf')
    max_db = float('-inf')
    for db in dbs:
        count += 1
        mean_db += db
        if (db > max_db):
            max_db = db
        elif (db < min_db):
            min_db = db
    mean_db = mean_db/count
    features_dict ['max_db'] = max_db
    features_dict ['min_db'] = min_db
    
    features_dict ['mean_db'] = mean_db

    #harmonicity analysis
    HNR = sig.get_HNR (signal, sr)
    features_dict ['HNR'] = HNR
    
#     features_dict['median_f0'] = np.median(features_dict['median_f0'])
    #features_dict['mean_db'] = np.mean(features_dict['mean_db'])
    return features_dict

# %%
#get tickers
#compute dict of {date:[{company:{feature:value}}]}
company_names_to_tickers = {}
num_calls = 0
for root, dirs, files in os.walk("ReleasedDataset_mp3"):
    for directory in dirs:
        try:
            if (directory == 'Audio'):
                continue
            company_name = directory[:directory.index('_')]
            date = directory[directory.index('_')+1:]
            ticker = name_convert(company_name)
            company_names_to_tickers [company_name] = ticker
        except:
            continue

# %%
company_names_to_tickers
# Out:
# {'Becton Dickinson': 'BDX',
#  'CIGNA Corp.': 'CI',
#  'The Bank of New York Mellon Corp.': 'bk',
#  'JPMorgan Chase & Co.': 'JPM',
#  'Martin Marietta Materials': 'MLM',
#  'Advanced Micro Devices Inc': 'AMD',
#  'Xcel Energy Inc': 'XEL',
#  'Electronic Arts': 'EA',
#  'NiSource Inc.': 'NI',
#  'Salesforce.com': 'CRM',
#  'Lilly (Eli) & Co.': 'LLY',
#  'Synopsys Inc.': 'SNPS',
#  'Illumina Inc': 'ILMN',
#  'Cboe Global Markets': 'CBOE',
#  'Gilead Sciences': 'GILD',
#  'Polo Ralph Lauren Corp.': 'RL',
#  'Waste Management Inc.': 'WM',
#  'Emerson Electric Company': 'EMR',
#  'Avery Dennison Corp': 'AVY',
#  'News Corp. Class A': 'NWS',
#  'Ecolab Inc.': 'ECL',
#  'Alliance Data Systems': 'ADS',
#  'Alaska Air Group Inc': 'ALK',
#  'CenturyLink Inc': 'LUMN',
#  'Intuit Inc.': 'INTU',
#  'Kraft Heinz Co': 'KHC',
#  'Comcast Corp.': 'CMCSA',
#  'Illinois Tool Works': 'ITW',
#  'Fortive Corp': 'FTV',
#  'PG&E Corp.': 'PG',
#  'Molson Coors Brewing Company': 'TAP',
#  'Mattel Inc.': 'MAT',
#  'Caterpillar Inc.': 'CAT',
#  'Sealed Air': 'SEE',
#  'Tiffany & Co.': 'lvmh-completes-acquisition-tiffany-co-134000015.html',
#  'The Mosaic Company': 'MOS',
#  'HP Inc.': 'HPQ',
#  'Merck & Co.': 'MRK',
#  'Altria Group Inc': 'MO',
#  'Hilton Worldwide Holdings Inc': 'HLT',
#  'Sherwin-Williams': 'shw',
#  'The Hershey Company': 'hsy',
#  'Ball Corp': 'BLL',
#  'Align Technology': 'ALGN',
#  'Lockheed Martin Corp.': 'LMT',
#  'Incyte': 'incy',
#  'Intel Corp.': 'INTC',
#  'Valero Energy': 'VLO',
#  'Aetna Inc': 'AET',
#  'Autodesk Inc.': 'ADSK',
#  'Thermo Fisher Scientific': 'TMO',
#  'Dover Corp.': 'DOV',
#  'Home Depot': 'HD',
#  'Campbell Soup': 'CPB',
#  'Sysco Corp.': 'SYY',
#  'Norwegian Cruise Line': 'NCLH',
#  'A.O. Smith Corp': 'AOS',
#  'XL Group': 'XL',
#  'Allegion': 'ALLE',
#  'FleetCor Technologies Inc': 'FLT',
#  '3M Company': 'MMM',
#  'Pinnacle West Capital': 'PNW',
#  'Dominion Energy': 'D',
#  'American Express Co': 'AXP',
#  'Western Union Co': 'WU',
#  'Roper Technologies': 'ROP',
#  'Digital Realty Trust Inc': 'DLR',
#  'CVS Health': 'CVS',
#  'Celgene Corp.': 'history',
#  'DTE Energy Co.': 'DTE',
#  'Nucor Corp.': 'NUE',
#  'Regions Financial Corp.': 'RF',
#  'The Walt Disney Company': 'DIS',
#  'Target Corp.': 'TGT',
#  'Johnson Controls International': 'JCI',
#  'Ingersoll-Rand PLC': 'IR',
#  'Fidelity National Information Services': 'FIS',
#  'Marsh & McLennan': 'MMC',
#  'Parker-Hannifin': 'PH',
#  'TE Connectivity Ltd.': 'TEL',
#  'F5 Networks': 'FFIV',
#  'Tractor Supply Company': 'TSCO',
#  'WestRock': 'WRK',
#  'Hologic': 'HOLX',
#  'LKQ Corporation': 'LKQ',
#  'Bristol-Myers Squibb': 'BMY',
#  'Church & Dwight': 'CHD',
#  'ABIOMED Inc': 'abmd',
#  'DaVita Inc.': 'DVA',
#  'Varian Medical Systems': 'VAR',
#  'MGM Resorts International': 'MGM',
#  'General Motors': 'GM',
#  'Kellogg Co.': 'K',
#  'Franklin Resources': 'BEN',
#  'Seagate Technology': 'STX',
#  "Kohl's Corp.": 'KSS',
#  'Equinix': 'EQIX',
#  'Boeing Company': 'BA',
#  "Lowe's Cos.": 'LOW',
#  'Darden Restaurants': 'DRI',
#  'Mastercard Inc.': 'MA',
#  'Agilent Technologies Inc': 'A',
#  'Kimberly-Clark': 'kmb',
#  'Yum! Brands Inc': 'YUM',
#  'Newell Brands': 'NWL',
#  'NRG Energy': 'NRG',
#  'Prologis': 'PLD',
#  'PPL Corp.': 'PPL',
#  'Grainger (W.W.) Inc.': 'GWW',
#  'Biogen Inc.': 'BIIb',
#  'Stericycle Inc': 'SRCL',
#  'Carmax Inc': 'KMX',
#  'Estee Lauder Cos.': 'EL',
#  'CMS Energy': 'CMS',
#  'Microsoft Corp.': 'MSFT',
#  'LyondellBasell': 'LYB',
#  'Amgen Inc.': 'Amgn',
#  'Conagra Brands': 'CAG',
#  'SVB Financial': 'SIVB',
#  'The Clorox Company': 'CLX',
#  'Xerox': 'XRX',
#  'CBRE Group': 'CBRE',
#  'Goldman Sachs Group': 'GS',
#  'Akamai Technologies Inc': 'AKAM',
#  'Baxter International Inc.': 'BAX',
#  'Garmin Ltd.': 'GRMN',
#  'Kroger Co.': 'KR',
#  'American Tower Corp A': 'AMT',
#  'Apache Corporation': 'APA',
#  'Adobe Systems Inc': 'ADBE',
#  'AmerisourceBergen Corp': 'ABC',
#  'Pentair plc': 'PNR',
#  'BorgWarner': 'BWA',
#  'Mondelez International': 'MDLZ',
#  'IPG Photonics Corp.': 'IPGP',
#  'Gap Inc.': 'GPS',
#  'Texas Instruments': 'TXN',
#  'Hess Corporation': 'HES',
#  'Ameren Corp': 'AEE',
#  'Automatic Data Processing': 'ADP',
#  'Amazon.com Inc.': 'AMZN',
#  'Hewlett Packard Enterprise': 'HPE',
#  'Hanesbrands Inc': 'HBI',
#  'Gartner Inc': 'IT',
#  'Oracle Corp.': 'ORCL',
#  'CBS Corp.': 'CBS',
#  'MSCI Inc': 'MSCI',
#  'Comerica Inc.': 'CMA',
#  'General Mills': 'GIS',
#  'Foot Locker Inc': 'FL',
#  'Cummins Inc.': 'CMI',
#  'Dish Network': 'DISH',
#  'Crown Castle International Corp.': 'CCI',
#  'International Paper': 'IP',
#  'D. R. Horton': 'DHI',
#  'Masco Corp.': 'mas',
#  'Norfolk Southern Corp.': 'NSC',
#  'Ulta Beauty': 'ULTA',
#  'Weyerhaeuser': 'WY',
#  'Hasbro Inc.': 'HAS',
#  "Edison Int'l": 'EIX',
#  'General Dynamics': 'GD',
#  'The Cooper Companies': 'COO',
#  'Abbott Laboratories': 'ABT',
#  'AES Corp': 'AES',
#  'Alexion Pharmaceuticals': 'alxn',
#  'Activision Blizzard': 'ATVI',
#  'Wec Energy Group Inc': 'WEC',
#  'Micron Technology': 'MU',
#  'SunTrust Banks': 'news',
#  'Cognizant Technology Solutions': 'CTSH',
#  'Chevron Corp.': 'CVX',
#  'Nvidia Corporation': 'NVDA',
#  'Citrix Systems': 'CTXS',
#  'Red Hat Inc.': 'RHI.F',
#  'Archer-Daniels-Midland Co': 'ADM',
#  'Corning Inc.': 'GLW',
#  'Interpublic Group': 'ipg',
#  'AMETEK Inc.': 'AME',
#  'Nektar Therapeutics': 'NKTR',
#  'SCANA Corp': 'SCG',
#  'Public Serv. Enterprise Inc.': 'PEG',
#  'Lennar Corp.': 'LEN',
#  'Walgreens Boots Alliance': 'WBA',
#  'Skyworks Solutions': 'SWKS',
#  'Fortune Brands Home & Security': 'FBHS',
#  'Duke Energy': 'DUK',
#  'Welltower Inc.': 'WELL',
#  'Kansas City Southern': 'KSU',
#  'Nielsen Holdings': 'NLSN',
#  'Sempra Energy': 'SRE',
#  'Goodyear Tire & Rubber': 'GT',
#  'Quest Diagnostics': 'DGX',
#  'Republic Services Inc': 'RSG',
#  'Snap-On Inc.': 'SNA',
#  'Tapestry, Inc.': 'TPR',
#  'Halliburton Co.': 'HAL',
#  'Regeneron': 'REGN',
#  'General Growth Properties Inc.': 'GGP',
#  'Nasdaq, Inc.': 'NDAQ',
#  'PayPal': 'PYPL',
#  'Verizon Communications': 'VZ',
#  'Iron Mountain Incorporated': 'IRM',
#  'ResMed': 'RMD',
#  'Anthem Inc.': 'ANTM',
#  'Booking Holdings Inc': 'BKNG',
#  'Raytheon Co.': 'RTX',
#  'U.S. Bancorp': 'USB',
#  'Kinder Morgan': 'KMI',
#  'Lam Research': 'LRCX',
#  'United Health Group Inc.': 'UNH',
#  'KLA-Tencor Corp.': 'KLAC',
#  'Schlumberger Ltd.': 'SLB',
#  'Ford Motor': 'F',
#  'NetApp': 'NTAP',
#  'Verisign Inc.': 'VRSN',
#  'Viacom Inc.': 'VIAC',
#  'Ross Stores': 'ROST',
#  'Fifth Third Bancorp': 'FITB',
#  'Invesco Ltd.': 'IVZ',
#  'AbbVie Inc.': 'ABBV',
#  'Humana Inc.': 'HUM',
#  'Coty, Inc': 'COTY',
#  'Cadence Design Systems': 'CDNS',
#  'Quanta Services Inc.': 'PWR',
#  'Motorola Solutions Inc.': 'msi',
#  'Intercontinental Exchange': 'ice',
#  'Cimarex Energy': 'XEC',
#  'Stryker Corp.': 'SYK',
#  "McDonald's Corp.": 'MCD',
#  'Juniper Networks': 'JNPR',
#  'PepsiCo Inc.': 'PEP',
#  'PACCAR Inc.': 'PCAR',
#  'Facebook, Inc.': 'FB',
#  'Freeport-McMoRan Inc.': 'FCX',
#  'Genuine Parts': 'GPC',
#  'Symantec Corp.': 'SYM.SG',
#  'Xilinx': 'XLNX',
#  'United Technologies': 'UTX',
#  'Advance Auto Parts': 'AAP',
#  'FLIR Systems': 'FLIR',
#  'Twitter, Inc.': 'TWTR',
#  'eBay Inc.': 'EBAY',
#  'Michael Kors Holdings': 'kors',
#  'Walmart': 'WMT',
#  'Perrigo': 'PRGO',
#  'Tyson Foods': 'TSN',
#  'Hormel Foods Corp.': 'HRL',
#  'Royal Caribbean Cruises Ltd': 'RCL',
#  'Rockwell Automation Inc.': 'ROK',
#  'Citigroup Inc.': 'C',
#  'Cisco Systems': 'CSCO',
#  'EQT Corporation': 'EQT',
#  'Allergan, Plc': 'AGN,+',
#  'Western Digital': 'WDC',
#  'Edwards Lifesciences': 'EW',
#  'Coca-Cola Company (The)': 'KO',
#  'AT&T Inc.': 'finance.yahoo.com',
#  'PPG Industries': 'PPG',
#  'Nordstrom': 'JWN',
#  'TransDigm Group': 'TDG',
#  'Ventas Inc': 'VTR',
#  'Harris Corporation': 'LHX',
#  'Noble Energy Inc': 'profile',
#  'CME Group Inc.': 'CME',
#  'Henry Schein': 'HSIC',
#  'Newmont Mining Corporation': 'NEM',
#  'HCA Holdings': 'HCA',
#  'Nike': 'NKE',
#  'PerkinElmer': 'pki',
#  'CA, Inc.': 'ca',
#  'Starbucks Corp.': 'SBUX',
#  'Exxon Mobil Corp.': 'XOM',
#  'United Parcel Service': 'UPS'}

# %%
def name_convert(self):

    searchval = 'yahoo finance '+self
    link = []
    #limits to the first link
    for url in search(searchval, lang='en', num_results=1):
        link.append(url)

    link = str(link[0])
    link=link.split("/")
    if link[-1]=='':
        ticker=link[-2]
    else:
        x=link[-1].split('=')
        ticker=x[-1]

    return(ticker)

# %%
#manually change some
company_names_to_tickers['Alliance Data Systems'] = 'ADS'
company_names_to_tickers['Tiffany & Co.'] = 'CELG'
company_names_to_tickers['SunTrust Banks'] = 'STI'
company_names_to_tickers['General Growth Properties Inc.'] = 'GGP'
company_names_to_tickers['AT&T Inc.'] = 'T'
company_names_to_tickers['Noble Energy Inc'] = 'NBLX'
company_names_to_tickers.pop('.ipynb', None)

# %%
len(company_names_to_tickers.keys())
# Out:
# 274

# %%
ticker_string = ''
for company_name in company_names_to_tickers.keys():
    ticker = company_names_to_tickers[company_name]
    ticker_string += ticker + ' '
ticker_string = ticker_string[:len(ticker_string)-1]
price_data = yf.download(ticker_string, start="2017-01-01", end="2017-12-31")
# Out:
# [*********************100%***********************]  275 of 275 completed
#
# 11 Failed downloads:
# - GGP: No data found for this date range, symbol may be delisted
# - CELG: No data found, symbol may be delisted
# - +: No data found, symbol may be delisted
# - STI: No data found, symbol may be delisted
# - KORS: No data found for this date range, symbol may be delisted
# - RHI.F: No data found, symbol may be delisted
# - CBS: No data found, symbol may be delisted
# - HISTORY: No data found, symbol may be delisted
# - AGN: No data found, symbol may be delisted
# - XL: Data doesn't exist for startDate = 1483257600, endDate = 1514707200
# - UTX: No data found, symbol may be delisted

# %%
#drop holidays
holidays = ['January 2, 2017', 'January 16, 2017', 'February 20, 2017', 'April 14, 2017', 'May 29, 2017', 
            'July 3, 2017', 'July 4, 2017', 'September 4, 2017', 'November 23, 2017', 'November 24, 2017', 
            'December 25, 2017']
parsed_holidays = [parser.parse(holiday) for holiday in holidays]   
drop_indices = []
for index in price_data.index:
    if (index in parsed_holidays):
        drop_indices.append(index)

# %%
price_data = price_data.drop(index = drop_indices)
price_data = price_data.dropna(axis = 1, how = 'all')

# %%
look_ahead_periods = [1, 3, 7, 14, 21, 28]
returns_data_master = {}
for date in list(data_master.keys()):
    try:
        returns_data_master[date] = []
        
        parsed_date = parser.parse(date)
        buy_date_index = price_data.index.get_loc(parsed_date) + 1
        buy_date = price_data.index[buy_date_index]
        company_list = data_master[date]
        for entry in company_list:
            company_name = list(entry.keys())[0]
            
            ticker = company_names_to_tickers[company_name]

            buy_price = price_data['Open'][ticker][buy_date]
            sell_prices = []

            for look_ahead in look_ahead_periods:
                sell_date_index = buy_date_index + look_ahead
                sell_date = price_data.index[sell_date_index]
                sell_price = price_data['Open'][ticker][sell_date]
                sell_prices.append(sell_price)

            returns = []
            for sell_price in sell_prices:
                returns.append((sell_price- buy_price)/buy_price)

            returns_data_master[date].append({company_name:returns})
    except:
        continue

# %%
combined_data = {}
for date in sorted(returns_data_master.keys()):
    company_list = returns_data_master[date]
    combined_data[date] = []
    for entry in company_list:
        company_name = list(entry.keys())[0]
        company_return = entry[company_name]
        features_list = data_master[date]
        for feature_entry in features_list:
            feature_company_name = list(feature_entry.keys())[0]
            if (feature_company_name == company_name):
                features = list(feature_entry[feature_company_name].values())
                combined_data[date].append([features, company_return])

# %%
for key in combined_data.keys():
    entry = combined_data[key]
    for pair in entry:
        features = pair[0]
        features[2] = features[2][0][0]

# %%
df_final = pd.DataFrame(columns = ['minimum_pitch','maximum_pitch','median_f0', 'number_of_pulses', 'jitter_local', 
                            'jitter_local_absolute', 'jitter_rap', 'jitter_ppq5', 'jitter_ddp', 'max_db', 
                            'min_db', 'mean_db', 'HNR', 'VADER_neg','VADER_neu','VADER_pos','VADER_compound',
                            'finBERT_pos', 'finBERT_neg','finBERT_neu','1_day_ret','3_day_ret', '7_day_ret', '14_day_ret', 
                            '21_day_ret', '28_day_ret'])

# %%
df_final = []
for date in sorted(combined_data.keys()):
    entry_list = combined_data[date]
    for entry in entry_list:
        features = entry[0]
        rets = entry[1]
        row = list(np.concatenate([features, rets]))
        df_final.append(row)

# %%
df_final = pd.DataFrame(df_final, columns = ['minimum_pitch','maximum_pitch','median_f0', 'number_of_pulses', 'jitter_local', 
                            'jitter_local_absolute', 'jitter_rap', 'jitter_ppq5', 'jitter_ddp', 'max_db', 
                            'min_db', 'mean_db', 'HNR', 'VADER_neg','VADER_neu','VADER_pos','VADER_compound',
                            'finBERT_pos', 'finBERT_neg','finBERT_neu','1_day_ret','3_day_ret', '7_day_ret', '14_day_ret', 
                            '21_day_ret', '28_day_ret'])

# %%
target_periods = ['1_day_ret','3_day_ret', '7_day_ret', '14_day_ret', 
                            '21_day_ret', '28_day_ret']
for target_period in target_periods:
    df_final[target_period] = df_final[target_period].apply(lambda x: x >0)

# %%
df_final = df_final.dropna(axis = 0, how = 'any')

# %%
pd.to_pickle(df_final, "df_final.pkl")

# %%
#correlation visualization
sns.heatmap(df_final.corr())

# %%
#random forest
train_idx = int(df_final.shape[0]*.8)
train_data = df_final[:train_idx]
test_data = df_final[train_idx:]

# %%
#eval baseline
features = train_data[['jitter_local_absolute']]

feature_list = list(features.columns)
features = np.array(features)

target_periods = ['1_day_ret','3_day_ret', '7_day_ret', '14_day_ret', 
                            '21_day_ret', '28_day_ret']

test_features =  test_data[['jitter_local_absolute']]

test_features = np.array(test_features)

for target_period in target_periods:
    print ('target period: ')
    print (target_period)
    print ()
    #fit
    
    target = np.array(train_data[target_period])
    
    rf = RandomForestClassifier(n_estimators = 1000, random_state = 42)
    rf.fit(features, target)
    
    #predict on test
    test_target = np.array(test_data[target_period])
    predictions = rf.predict(test_features)
    
    f1 = f1_score(predictions, test_target)
    accuracy = accuracy_score (predictions, test_target)
    print ('f1: ')
    print (f1)
    print()
    
    print ('accuracy: ')
    print (accuracy)
    print()

# %%
#eval full model
features = train_data[['minimum_pitch','maximum_pitch','median_f0', 'number_of_pulses', 'jitter_local', 
                            'jitter_local_absolute', 'jitter_rap', 'jitter_ppq5', 'jitter_ddp', 'max_db', 
                            'min_db', 'mean_db', 'HNR']]

feature_list = list(features.columns)
features = np.array(features)

target_periods = ['1_day_ret','3_day_ret', '7_day_ret', '14_day_ret', 
                            '21_day_ret', '28_day_ret']

test_features =  test_data[['minimum_pitch','maximum_pitch','median_f0', 'number_of_pulses', 'jitter_local', 
                            'jitter_local_absolute', 'jitter_rap', 'jitter_ppq5', 'jitter_ddp', 'max_db', 
                            'min_db', 'mean_db', 'HNR']]

test_features = np.array(test_features)

for target_period in target_periods:
    print ('target period: ')
    print (target_period)
    print ()
    #fit
    
    target = np.array(train_data[target_period])
    
    rf = RandomForestClassifier(n_estimators = 1000, random_state = 42)
    rf.fit(features, target)
    
    #predict on test
    test_target = np.array(test_data[target_period])
    predictions = rf.predict(test_features)
    
    f1 = f1_score(predictions, test_target)
    accuracy = accuracy_score (predictions, test_target)
    print ('f1: ')
    print (f1)
    print()
    
    print ('accuracy: ')
    print (accuracy)
    print()
    
    print ('feature importances: ')
    #feature importances
    importances = rf.feature_importances_
    plt.rcParams["figure.figsize"] = (40, 20)
    plt.bar(feature_list, importances)
    plt.show()
